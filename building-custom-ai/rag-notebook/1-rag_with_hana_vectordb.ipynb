# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="./images/btp-banner.gif" alt="BTP A&C">
# </div>

# %% [markdown]
# ## Retrieval-Augmented Generation with SAP HANA Cloud Vector Engine
#
# In this demo, we will explore how to enhance the capabilities of Large Language Models (LLMs) with **SAP HANA Cloud vector engine**. You will learn how to embed unstructured and semi-structured data using LLMs from **SAP Generative AI Hub**, store the vector embeddings in **SAP HANA Cloud**. Additionally, you will query vector embeddings, and forward the relevant results to a LLM to generate an augmented answer.

# %% [markdown]
# ## 🎯Learning Objectives
# By the end of this demo, you will be able to:
# - Implement a full RAG pipeline using Python, LangChain, and Generative AI Hub SDK.
# - Generate embeddings for document chunks using Generative AI Hub SDK.
# - Retrieve the most relevant content based on semantic similarity using SAP HANA Cloud similarity search.
# - Augment user prompts with retrieved context and invoke LLMs (e.g., GPT-5) to generate more accurate, grounded answers.
# - Design and use prompt templates to enhance the quality of generated responses.

# %% [markdown]
# ## 🚨Requirements
#
# Please review the following requirements before starting the demo:
# - Enable the additional feature **Natural Language Processing (NPL)** in your SAP HANA Cloud database
# - Deploy Large Language Models (LLMs): **text-embedding-3-large** and **gpt-5** in SAP AI Launchpad

# %% [markdown]
# ## 📝About the Data
#
# The data set is a product catalog of IT accessory products. Here are the main attributes and their descriptions based on the sample data:
#
# |Field          |Description            |
# ----------------|-----------------------
# |**PRODUCT_ID**| A unique identifier for each product.|
# |**PRODUCT_NAME**| The name of the product, which typically includes the brand and the model.|
# |**CATEGORY**| The general category of the product, which is "IT Accessories" for all entries sampled.|
# |**DESCRIPTION**| A detailed description of the product, highlighting key features and specifications.|
# |**UNIT_PRICE**| The price of the product in Euros.|
# |**UNIT_MEASURE**| The unit of measure for the product, typically "Each" indicating pricing per item.|
# |**SUPPLIER_ID**| A unique identifier for the supplier of the product.|
# |**SUPPLIER_NAME**| The name of the supplier.|
# |**LEAD_TIME_DAYS**| The number of days it takes from order to delivery.|
# |**MIN_ORDER**| The minimum order quantity required.|
# |**CURRENCY**| The currency of the transaction, which is "EURO" for all entries.|
# |**SUPPLIER_COUNTRY**| The country where the supplier is located, which is "Germany" for all sampled entries.|
# |**SUPPLIER_ADDRESS**| The physical address of the supplier.|
# |**AVAILABILITY_DAYS**| The number of days the product is available for delivery.|
# |**SUPPLIER_CITY**| The city where the supplier is located.|
# |**STOCK_QUANTITY**| The quantity of the product currently in stock.|
# |**MANUFACTURER**| The company that manufactured the product.|
# |**CITY_LAT**| Geographical coordinates of the city (latitude)|
# |**CITY_LONG**| Geographical coordinates of the city (longitude).|
# |**RATING:**| A rating for the product, which are on a scale from 1 to 5.|
#
# </br>
#
# This dataset is structured to support various business operations such as inventory management, order processing, and logistics planning, providing a comprehensive view of product offerings, supplier details, and stock levels. Each entry is highly detailed, suggesting the dataset could be used for analytical purposes, such as optimizing supply chain operations or analyzing sales and marketing strategies.
#
# </br>

# %% [markdown]
# ## Retrieval Augmented Generation using generative AI Hub and SAP HANA Vector Engine
#
# ### Hands-on Retrieval Augmented Generation (RAG) workflow
#
# The Retrieval Augmented Generation use case process consists of steps to be completed as seen in the graphic below.
#
# <br>
#
#
# > ![title](./images/rag_full.png)
#
# <br>
#
#
# #### Indexing Process
# 1. Business documents that should be used for answering user questions are fed into the model. The contents of the files are split into smaller chunks.
#     >"Chunking" (and sometimes called "LLM chunking") refers to dividing a large text corpus into smaller, manageable pieces or segments. Each recursive chunking part acts as a standalone unit of information that can be individually indexed and retrieved.
# 2. Embedding functions are used to create embeddings from the file/document chunks.
#     >Embeddings refer to dense, continuous vectors representing text in a high-dimensional space. These vectors serve as coordinates in a semantic space, capturing the relationships and meanings between words.
# 3. The embeddings are then stored as vectors in the SAP HANA Cloud Database.
# #### Retrieval Process
# 1. A query or prompt is submitted.
# 2. The query embedded into a vector form.
# 3. The query vector is compared to the values stored as vectors in SAP HANA Cloud via a similarity/semantic search.
# 4. The most appropriate and relevant results are identified.
# 5. And forwarded, along with the original query, to a large language model such as GPT-5.
# 6. The LLM uses the results of the HANA vector search to augment its own searching capabilities, and the final answer is returned to the user.
#
#
# <!-- - Uses Python code to generate responses for queries using the SDK.
#
# - Formats the query and invokes the Generative AI Hub SDK to fetch responses. -->
#
# ### Implementing RAG Embeddings
#
# - Prepare the documentation for the product catalog in CSV format with each row representing a product.
#
# - Connect to the HANA vector storage instance and create a table to store the documentation data.
#
# - Populate the table with data and create a REAL_VECTOR column to store embeddings.
#
# - Use the Generative AI Hub SDK to define a function to generate embeddings for prompts and perform similarity search using the embeddings.
#
# ### Enhancing Query Responses
#
# - Define a prompt template to provide context to queries.
#
# - Modify the function to query the LLM (Large Language Model) based on the prompt template.
#
# - Test the model's response using specific queries related to the node library, ensuring it provides contextually relevant responses based on embeddings.
#
# > Retrieval augmented generation optimizes the output of large language models by applying more context to prompts.
#
# </br>
#
# <!-- ### SAP HANA Cloud vector engine
#
# Storing vector embeddings within the same database is a strategic move that aligns seamlessly with SAP's commitment to providing a unified platform. This integration eliminates the hurdles posed by data silos, offering a holistic approach to data management. In SAP HANA Cloud, the storage of vector embeddings is seamlessly integrated into the platform's existing structure, allowing users to store them in a designated table. Developers can perform SQL-like queries effortlessly.
#
# This means you can execute joins, apply filters, and perform selects by combining vector embeddings with various data types, including transactional, spatial, graph, and JSON data, all within the same SQL environment. The Vector Engine ensures a user-friendly experience, eliminating the need for extensive learning or the adoption of new querying methodologies. Essentially, working with vector embeddings in SAP HANA Cloud is as straightforward as crafting queries in a standard SQL database, offering familiarity and ease of use for developers. -->
#
# <!-- ### Hands-on Retrieval Augmented Generation (RAG) workflow  -->
#
#
#
# <!-- 1. Documents to be included in vector analysis are fed into the model.
#
# 2. The contents of the files are split into smaller chunks.
#
# 3. Embedding functions are used to create embeddings from the file/document chunks.
#
# 4. The embeddings are then stored as vectors in the SAP HANA Cloud Database.
#
# 5. When a query or prompt is submitted, the query itself is then embedded into vector form.
#
# 6. The query vector is compared to the values stored as vectors in SAP HANA Cloud via a similarity/semantic search.
#
# 7. The most appropriate results are forwarded, along with the original query, to a large language model such as Chat GPT.
#
# 8. The LLM uses the results of the HANA vector search to augment its own searching capabilities, and the final answer is returned to the user. -->

# %% [markdown]
# ## Setup and configuration
#
# The following Python modules are to be installed during this hands-on introduction.
#
# #### **generative-ai-hub-sdk**
#
# With this SAP python SDK you can leverage the power of generative Models like chatGPT available in SAP's generative AI Hub.
#
# For more information, please see https://pypi.org/project/generative-ai-hub-sdk/
#
# #### **hdbcli**
#
# The Python Database API Specification v2.0 (PEP 249) defines a set of methods that provides a consistent database interface independent of the actual database being used. The Python extension module for SAP HANA implements PEP 249. Once you install the module, you can access and change the information in SAP HANA databases from Python.
#
# For more information, please see https://pypi.org/project/hdbcli/
#
# #### **langchain-hana**
#
# Integrates LangChain with SAP HANA Cloud to make use of vector search, knowledge graph, and further in-database capabilities as part of LLM-driven applications.
#
# For more information, please see https://pypi.org/project/langchain-hana/
#
#
# </br>
#
# #### Install Python packages
#
# Run the following package installations. **pip** is the package installer for Python. You can use pip to install packages from the Python Package Index and other indexes.

# %%
# %pip install "sap-ai-sdk-gen[all]" --break-system-packages
# %pip install hdbcli --break-system-packages
# %pip install langchain-hana --break-system-packages
# %pip install langchain langchain-community langchain-text-splitters --break-system-packages

# kernel restart required!!!
# Out:
# Requirement already satisfied: sap-ai-sdk-gen[all] in ./.venv/lib/python3.14/site-packages (6.1.2)
# Requirement already satisfied: h11>=0.16.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (0.16.0)
# Requirement already satisfied: langchain~=1.2.6 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.2.10)
# Requirement already satisfied: pydantic~=2.12 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (2.12.5)
# Requirement already satisfied: sap-ai-sdk-core>=3.1.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (3.1.6)
# Requirement already satisfied: langchain-openai~=1.1.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.1.10)
# Requirement already satisfied: langchain-community~=0.4.1 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (0.4.1)
# Requirement already satisfied: packaging>=23.2 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (26.0)
# Requirement already satisfied: click>=8.1.7 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (8.3.1)
# Requirement already satisfied: httpx>=0.27.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (0.28.1)
# Requirement already satisfied: openai>=1.58.1 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (2.24.0)
# Requirement already satisfied: langchain-classic~=1.0.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.0.1)
# Requirement already satisfied: overloading==0.5.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (0.5.0)
# Requirement already satisfied: dacite>=1.8.1 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.9.2)
# Requirement already satisfied: langchain-google-genai~=4.2.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (4.2.1)
# Requirement already satisfied: aioboto3==15.5.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (15.5.0)
# Requirement already satisfied: boto3==1.40.61 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.40.61)
# Requirement already satisfied: langchain-aws~=1.1.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.1.0)
# Requirement already satisfied: google-genai~=1.60.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-gen[all]) (1.60.0)
# Requirement already satisfied: aiobotocore==2.25.1 in ./.venv/lib/python3.14/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (2.25.1)
# Requirement already satisfied: aiofiles>=23.2.1 in ./.venv/lib/python3.14/site-packages (from aioboto3==15.5.0->sap-ai-sdk-gen[all]) (25.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (3.13.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (0.13.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.40.61)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (6.7.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in ./.venv/lib/python3.14/site-packages (from aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.17.3)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in ./.venv/lib/python3.14/site-packages (from boto3==1.40.61->sap-ai-sdk-gen[all]) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.23.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.venv/lib/python3.14/site-packages (from botocore<1.40.62,>=1.40.46->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (2.6.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in ./.venv/lib/python3.14/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (2.48.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (9.1.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (1.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.14/site-packages (from google-genai~=1.60.0->sap-ai-sdk-gen[all]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.14/site-packages (from anyio<5.0.0,>=4.8.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (4.9.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (1.0.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in ./.venv/lib/python3.14/site-packages (from langchain~=1.2.6->sap-ai-sdk-gen[all]) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langchain~=1.2.6->sap-ai-sdk-gen[all]) (1.0.10)
# Requirement already satisfied: numpy<3,>=2.3.2 in ./.venv/lib/python3.14/site-packages (from langchain-aws~=1.1.0->sap-ai-sdk-gen[all]) (2.4.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in ./.venv/lib/python3.14/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.7.10)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (6.0.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (2.0.48)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./.venv/lib/python3.14/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./.venv/lib/python3.14/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain~=1.2.6->sap-ai-sdk-gen[all]) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain~=1.2.6->sap-ai-sdk-gen[all]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain~=1.2.6->sap-ai-sdk-gen[all]) (3.0.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in ./.venv/lib/python3.14/site-packages (from langchain-google-genai~=4.2.0->sap-ai-sdk-gen[all]) (1.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in ./.venv/lib/python3.14/site-packages (from langchain-openai~=1.1.0->sap-ai-sdk-gen[all]) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain~=1.2.6->sap-ai-sdk-gen[all]) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.14/site-packages (from openai>=1.58.1->sap-ai-sdk-gen[all]) (0.13.0)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.14/site-packages (from openai>=1.58.1->sap-ai-sdk-gen[all]) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.2.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore==2.25.1->aiobotocore[boto3]==2.25.1->aioboto3==15.5.0->sap-ai-sdk-gen[all]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.28.1->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (3.4.4)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.14/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (0.6.2)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.14/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai~=1.1.0->sap-ai-sdk-gen[all]) (2026.2.28)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.1.0)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai~=1.60.0->sap-ai-sdk-gen[all]) (3.0)
# Requirement already satisfied: sap-ai-sdk-base~=3.2 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-core>=3.1.0->sap-ai-sdk-gen[all]) (3.2.3)
# Requirement already satisfied: aenum~=3.1 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-base~=3.2->sap-ai-sdk-core>=3.1.0->sap-ai-sdk-gen[all]) (3.1.16)
# Requirement already satisfied: pyhumps~=3.0 in ./.venv/lib/python3.14/site-packages (from sap-ai-sdk-base~=3.2->sap-ai-sdk-core>=3.1.0->sap-ai-sdk-gen[all]) (3.8.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: hdbcli in ./.venv/lib/python3.14/site-packages (2.27.23)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-hana in ./.venv/lib/python3.14/site-packages (1.0.2)
# Requirement already satisfied: hdbcli<3.0.0,>=2.23.24 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (2.27.23)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (1.2.10)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (1.2.17)
# Requirement already satisfied: numpy>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (2.4.2)
# Requirement already satisfied: rdflib<8.0.0,>=7.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-hana) (7.6.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langchain<2.0.0,>=1.0.0->langchain-hana) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.14/site-packages (from langchain<2.0.0,>=1.0.0->langchain-hana) (2.12.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (0.7.10)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-hana) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-hana) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (0.25.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=1.0.0->langchain-hana) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-hana) (0.4.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from rdflib<8.0.0,>=7.0.0->langchain-hana) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic<2.0.0,>=1.0.0->langchain-hana) (2.6.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in ./.venv/lib/python3.14/site-packages (1.2.10)
# Requirement already satisfied: langchain-community in ./.venv/lib/python3.14/site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in ./.venv/lib/python3.14/site-packages (1.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in ./.venv/lib/python3.14/site-packages (from langchain) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.14/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.10)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in ./.venv/lib/python3.14/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in ./.venv/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.14/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./.venv/lib/python3.14/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in ./.venv/lib/python3.14/site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./.venv/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Restart Python kernel
#
# The Python kernel needs to be restarted before continuing.
#
# > ![title](./images/config_001.png)

# %% [markdown]
# #### Configure SAP Generative AI Hub credentials
#
# Execute the configuration module below to enable access to SAP Generative AI foundation models. This configuration is automatically done by running configuration module in the code block.
#
# You could also set up the same by running a terminal command: **aicore configure**
#
#
# </br>
#
# > Please ensure that the Python kernel was restarted!

# %%
# Generative AI Config
import os
import json

with open(os.path.join(os.getcwd(), 'env_config.json')) as f:
    aicore_config = json.load(f)

# %% [markdown]
# ### Initialize the LLM model
# LLM is initialized as an instance of ChatOpenAI with a model **gpt-5**. This is used for generating responses or interacting in a chat-like environment.
#
# > **IMPORTANT!** here you are connecting to the **gpt-5** model that was deployed in SAP AI Core.
# <!-- We can compare how the output produced by RAG is different from the output when we directly pass the prompt to the model. If we directly pass the prompt to the model without RAG, this will be the output. -->

# %%
# Set llm
from ai_core_sdk.ai_core_v2_client import AICoreV2Client
from gen_ai_hub.proxy.gen_ai_hub_proxy import GenAIHubProxyClient
# harmonized init helper
from gen_ai_hub.proxy.langchain.init_models import init_llm

# Set up the AICoreV2Client
ai_core_client = AICoreV2Client(base_url=aicore_config['AICORE_BASE_URL'],
                            auth_url=aicore_config['AICORE_AUTH_URL'],
                            client_id=aicore_config['AICORE_CLIENT_ID'],
                            client_secret=aicore_config['AICORE_CLIENT_SECRET'],
                            resource_group=aicore_config['AICORE_RESOURCE_GROUP'])
# Set up the GenAIHubProxyClient
proxy_client = GenAIHubProxyClient(ai_core_client = ai_core_client)
print("✅AI Core Client connection is established successfully!")

# Set up the LLM model (here we are using GPT-5 as an example but you can choose any available model from here https://help.sap.com/doc/generative-ai-hub-sdk/CLOUD/en-US/_reference/README_sphynx.html#supported-models)
llm = init_llm('gpt-5', proxy_client=proxy_client, max_tokens=30000)
print("✅LLM model connection is established successfully!")
# Out:
# ✅AI Core Client connection is established successfully!
# ✅LLM model connection is established successfully!

# %% [markdown]
# ### Ask LLM without context
#
# After completing the configuration we are ready to ask the first question directly to LLM (gpt-5) without any business product context to find us products with a rating of 4 and more. The response is arbitrary and does not relate to our product data.
#
# </br>
#
# > **Note** We can solve this problem by following the next steps in implementing RAG Embeddings.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from IPython.display import Markdown

template = """Question: {question}"""
prompt = PromptTemplate(template=template, input_variables=['question'])
question = "Return one keyboard suggestion (brand + model) with rating ≥4. Format as: 'Keyboard: <name>'"

chain = prompt | llm | StrOutputParser()
response = chain.invoke({'question': question})

display(Markdown(response))
# Out:
# Keyboard: Logitech MX Keys

# %% [markdown]
# # Implementing Retrieval Augmented Generation (RAG)
#
# ### Prepare the documentation for the product catalog in CSV format with each row representing a product
#
# This code snippet demonstrates how to load and process text data from a CSV file using the `CSVLoader` from the `langchain.document_loaders.csv_loader` module.
#
# This process is useful for handling large text data, making it more manageable or suitable for further processing, analysis, or input into machine learning models, especially when dealing with limitations on input size.

# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders.csv_loader import CSVLoader

# Process CSV data file
loader = CSVLoader(
    file_path="data/product_catalog.csv",
    csv_args={
        "delimiter": ";",
        "quotechar": '"'
        
    },
)

# Process data
text_documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
text_chunks = text_splitter.split_documents(text_documents)

print(f"Number of document chunks: {len(text_chunks)}")

for chunks in text_chunks:
    print(chunks.metadata)
    print(chunks.page_content)
# Out:
# Number of document chunks: 75
# {'source': 'data/product_catalog.csv', 'row': 0}
# ﻿PRODUCT_ID: P_0110
# PRODUCT_NAME: Logitech Signature M650 L Full Size Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Scroll smarter: With Logitech Signature M650 Wireless Mouse you get line-by-line precision for documents and super-fast scrolling for long web pages
# UNIT_PRICE: 34,75
# SUPPLIER_ID: 1000
# SUPPLIER_NAME: Electro Semicon
# LEAD_TIME_DAYS: 13
# MIN_ORDER: 32
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Holzhausenstraße 6, 60318 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 104
# MANUFACTURER: Logitech
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 1}
# ﻿PRODUCT_ID: P_0138
# PRODUCT_NAME: Logitech G305 LIGHTSPEED Wireless Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: HERO Gaming Sensor: Next-gen HERO mouse sensor delivers up to 10x the power efficiency over other gaming mice with exceptional accuracy and responsiveness thanks to 400 IPS precision and up to 12000 DPI sensitivity
# UNIT_PRICE: 147,25
# SUPPLIER_ID: 1001
# SUPPLIER_NAME: Electro Circuits
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 39
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hochpfortenbüchel 2B, 50676 Köln, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Cologne
# STOCK_QUANTITY: 498
# MANUFACTURER: Logitech
# CITY_LAT: 43.7218277
# CITY_LONG: 0.9774958
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 2}
# ﻿PRODUCT_ID: P_0053
# PRODUCT_NAME: Logitech M185 Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Compact Mouse: With a comfortable and contoured shape, this Logitech ambidextrous wireless mouse feels great in either right or left hand and is far superior to a touchpad. This wireless USB mouse features a line-by-line scroll wheel, up to 1 year of battery life (2) thanks to a smart sleep mode function, and comes with the included AA battery
# UNIT_PRICE: 295,93
# SUPPLIER_ID: 1002
# SUPPLIER_NAME: Infinity Networks
# LEAD_TIME_DAYS: 13
# MIN_ORDER: 23
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: 44147 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 735
# MANUFACTURER: Cherry
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 3}
# ﻿PRODUCT_ID: P_0125
# PRODUCT_NAME: HP 150 Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 600 DPI Optical Mouse Sensor, 2.4GHz Wireless USB Receiver Included, Ambidextrous Design, 3 Buttons, Scroll Wheel, Up to 10 Month Battery, Black
# UNIT_PRICE: 240,69
# SUPPLIER_ID: 1003
# SUPPLIER_NAME: Optima Networks
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 5
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Kaiserstraße 34, 44135 Dortmund, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 0
# MANUFACTURER: HP
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 4}
# ﻿PRODUCT_ID: P_0118
# PRODUCT_NAME: Logitech ERGO K860
# CATEGORY: IT Accessories
# DESCRIPTION: Logitech ERGO K860 Wireless Ergonomic Keyboard
# UNIT_PRICE: 239,18
# SUPPLIER_ID: 1004
# SUPPLIER_NAME: Vertex Semicon
# LEAD_TIME_DAYS: 1
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lange Str. 62, 44137 Dortmund, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 0
# MANUFACTURER: Logitec
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 5}
# ﻿PRODUCT_ID: P_0129
# PRODUCT_NAME: Arteck Split Ergonomic Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Arteck Split Ergonomic Keyboard with Cushioned Wrist and Palm Rest, 2.4G USB Wireless Comfortable Natural Ergonomic Split Keyboard
# UNIT_PRICE: 246,11
# SUPPLIER_ID: 1005
# SUPPLIER_NAME: Precision Dynamics
# LEAD_TIME_DAYS: 11
# MIN_ORDER: 26
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Otto-Hahn-Straße 12, 44227 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 768
# MANUFACTURER: Arteck
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 6}
# ﻿PRODUCT_ID: P_0123
# PRODUCT_NAME: TECKNET Wireless Mouse for Laptop
# CATEGORY: IT Accessories
# DESCRIPTION: 4800 DPI Optical Computer Mice with 6 Adjustable Levels, 30 Months Long Battery Life 2.4G Cordless USB Silent Mouse for Notebook, PC, Office Home Work (Grey)
# UNIT_PRICE: 272,09
# SUPPLIER_ID: 1006
# SUPPLIER_NAME: Quantum Semicon
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 33
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Eschborner Landstraße 55, 60489 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 221
# MANUFACTURER: TECKNET
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 2
# {'source': 'data/product_catalog.csv', 'row': 7}
# ﻿PRODUCT_ID: P_0074
# PRODUCT_NAME: GeekerChip Rechargeable Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Bluetooth Mouse, Two Modes (BT 5.1 + 2.4G Wireless), Ultra-Thin/Silent (800-1200-1600), with USB cable, Wireless Mouse for PC/Tablet/Laptop(Black)
# UNIT_PRICE: 258,9
# SUPPLIER_ID: 1007
# SUPPLIER_NAME: Hyper Labs
# LEAD_TIME_DAYS: 9
# MIN_ORDER: 49
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Südwall, 44137 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 769
# MANUFACTURER: GeekerChip
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 8}
# ﻿PRODUCT_ID: P_0115
# PRODUCT_NAME: Logitech M330 SILENT PLUS Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 2.4GHz with USB Nano Receiver, 1000 DPI Optical Tracking, 2-year Battery Life, Compatible with PC, Mac, Laptop, Chromebook
# UNIT_PRICE: 69,62
# SUPPLIER_ID: 1008
# SUPPLIER_NAME: Digital Works
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 16
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Thorwaldsenstraße 11, 51103 Köln, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Cologne
# STOCK_QUANTITY: 0
# MANUFACTURER: Logitech
# CITY_LAT: 43.7218277
# CITY_LONG: 0.9774958
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 9}
# ﻿PRODUCT_ID: P_0048
# PRODUCT_NAME: VENTION Docking Station Dual Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: 16 IN 1 USB C Docking Station: VENTION laptop docking station features 2×4K@60Hz HDMI Ports, 4K@60Hz DP Port, 10Gbps USB C Port, 2x10Gbps USB A Ports, USB C Port, USB 3.0 Ports, 2xUSB 2.0 Ports, 100W Power Delivery (PD) Port, 3.5mm Audio Port, SD/TF Reader, PC Host Port and RJ45 Gigabit Ethernet, catering to all your daily needs
# UNIT_PRICE: 131,53
# SUPPLIER_ID: 1009
# SUPPLIER_NAME: Byte Works
# LEAD_TIME_DAYS: 14
# MIN_ORDER: 24
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Essen Schützenbahn 70, 45127 Essen, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Essen
# STOCK_QUANTITY: 416
# MANUFACTURER: VENTION
# CITY_LAT: 51.4582235
# CITY_LONG: 7.0158171
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 10}
# ﻿PRODUCT_ID: P_0111
# PRODUCT_NAME: UGREEN 2.4G Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Laptop, 4000 DPI 5 Adjustable Levels Ergonomic USB Wireless Mouse Compatible With PC MacBook Chromebook, 18-Month Battery Life (Black)
# UNIT_PRICE: 34,75
# SUPPLIER_ID: 1010
# SUPPLIER_NAME: Circuit Micro
# LEAD_TIME_DAYS: 13
# MIN_ORDER: 32
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Holzhausenstraße 6, 60318 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 104
# MANUFACTURER: UGREEN
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 11}
# ﻿PRODUCT_ID: P_0139
# PRODUCT_NAME: FUGACI Wireless Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 2 USB A to USB C Adapter, 2.4GHZ Bluetooth Mouse Rechargeable, Laptop Mouse Computer Accessories, USB Mouse 3 Buttons-Laptop Mouse Wireless PC Mouse 800 to 2400 Dpi
# UNIT_PRICE: 147,25
# SUPPLIER_ID: 1011
# SUPPLIER_NAME: Logic Supplies
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 39
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hochpfortenbüchel 2B, 50676 Köln, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Cologne
# STOCK_QUANTITY: 0
# MANUFACTURER: FUGACI
# CITY_LAT: 43.7218277
# CITY_LONG: 0.9774958
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 12}
# ﻿PRODUCT_ID: P_0052
# PRODUCT_NAME: JLab Go Work Wireless Headset
# CATEGORY: IT Accessories
# DESCRIPTION: Microphone for Laptop, 45+ Hr Playtime Bluetooth PC Headset, Multipoint Connect to Computer & Mobile, On Ear Wired or Wireless Headphones with Microphone
# UNIT_PRICE: 295,93
# SUPPLIER_ID: 1012
# SUPPLIER_NAME: Neo Wave
# LEAD_TIME_DAYS: 13
# MIN_ORDER: 23
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: 44147 Dortmund, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 0
# MANUFACTURER: JLab
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 2
# {'source': 'data/product_catalog.csv', 'row': 13}
# ﻿PRODUCT_ID: P_0124
# PRODUCT_NAME: Rebocico USB Headset with Microphone Noise Cancelling
# CATEGORY: IT Accessories
# DESCRIPTION: & Audio Controls, 3.5mm/USB Jack 2-In-1 Computer Office Teams Headsets, PC Headphone for laptop Skype Call Center, Business Chat, Teaching(1-Black)
# UNIT_PRICE: 240,69
# SUPPLIER_ID: 1013
# SUPPLIER_NAME: Precision Links
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 5
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Kaiserstraße 34, 44135 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 8
# MANUFACTURER: Rebocico
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 14}
# ﻿PRODUCT_ID: P_0117
# PRODUCT_NAME: Kensington Pro Fit Ergonomic Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Kensington Pro Fit Ergo Wireless Keyboard, QWERTY keyboard layout, Dual 2.4 GHz and Bluetooth 4.2 technology
# UNIT_PRICE: 239,18
# SUPPLIER_ID: 1014
# SUPPLIER_NAME: Neo Dynamics
# LEAD_TIME_DAYS: 1
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lange Str. 62, 44137 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 808
# MANUFACTURER: Kensington
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 15}
# ﻿PRODUCT_ID: P_0128
# PRODUCT_NAME: Microsoft L5V-00006 Sculpt Ergonomic Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Microsoft L5V-00006 Sculpt Ergonomic Desktop Keyboard
# UNIT_PRICE: 246,11
# SUPPLIER_ID: 1015
# SUPPLIER_NAME: Electro Industries
# LEAD_TIME_DAYS: 11
# MIN_ORDER: 26
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Otto-Hahn-Straße 12, 44227 Dortmund, Germany
# STATUS: NOT AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 0
# MANUFACTURER: Microsoft
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 16}
# ﻿PRODUCT_ID: P_0122
# PRODUCT_NAME: Sennheiser PC 5.2 CHAT, wired headset for relaxed gaming
# CATEGORY: IT Accessories
# DESCRIPTION: FOCUSED AT WORK - The headset with microphone has soft ear pads. These are so comfortable that you can wear the headphones with microphone all day long. Nothing distracts you from your work. NOISE CANCELLING HEADPHONES WITH NOISE-CANCELLING TECHNOLOGY — Your voice is heard clearly thanks to the noise-canceling microphone.
# UNIT_PRICE: 272,09
# SUPPLIER_ID: 1016
# SUPPLIER_NAME: Volt Dynamics
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 33
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Eschborner Landstraße 55, 60489 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 221
# MANUFACTURER: Sennheiser
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 17}
# ﻿PRODUCT_ID: P_0073
# PRODUCT_NAME: Link Dream USB Headsets with Microphone
# CATEGORY: IT Accessories
# DESCRIPTION: Clear Sound Quality: Link Dream H365 USB Headset with Microphone built-in a sound card, which enabled the newest unidirectional noise-reduction tech aims to improve voice clarity. Professional business headsets with microphone born for audio and online chat, providing high-quality stereo sound for conversation.
# UNIT_PRICE: 258,9
# SUPPLIER_ID: 1017
# SUPPLIER_NAME: Optima Micro
# LEAD_TIME_DAYS: 9
# MIN_ORDER: 49
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Südwall, 44137 Dortmund, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dortmund
# STOCK_QUANTITY: 769
# MANUFACTURER: Link Dream
# CITY_LAT: 51.5142273
# CITY_LONG: 7.4652789
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 18}
# ﻿PRODUCT_ID: P_0114
# PRODUCT_NAME: TECKNET Wireless Headset with Microphone Noise Cancelling
# CATEGORY: IT Accessories
# DESCRIPTION: Bluetooth Headset with Microphone for Laptop, All Day Battery Life with Charging Dock for Office, Home, Remote Work, Call Center and More
# UNIT_PRICE: 69,62
# SUPPLIER_ID: 1018
# SUPPLIER_NAME: Hyper Components
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 16
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Thorwaldsenstraße 11, 51103 Köln, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Cologne
# STOCK_QUANTITY: 909
# MANUFACTURER: TECKNET
# CITY_LAT: 43.7218277
# CITY_LONG: 0.9774958
# RATING: 2
# {'source': 'data/product_catalog.csv', 'row': 19}
# ﻿PRODUCT_ID: P_0047
# PRODUCT_NAME: Mosiriui USB C Docking Station Dual Monitor14 IN 1USB C HUB Multiport Adapter
# CATEGORY: IT Accessories
# DESCRIPTION: Wireless mouse with multi-device connectivity
# UNIT_PRICE: 131,53
# SUPPLIER_ID: 1019
# SUPPLIER_NAME: Blue Components
# LEAD_TIME_DAYS: 14
# MIN_ORDER: 24
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Essen Schützenbahn 70, 45127 Essen, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Essen
# STOCK_QUANTITY: 416
# MANUFACTURER: Mosiriui
# CITY_LAT: 51.4582235
# CITY_LONG: 7.0158171
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 20}
# ﻿PRODUCT_ID: P_0140
# PRODUCT_NAME: Razer DeathAdder V2 Pro Wireless Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Razer HyperSpeed Wireless Technology, 20K Optical Sensor, 8 Programmable Buttons, RGB Chroma Lighting
# UNIT_PRICE: 229,99
# SUPPLIER_ID: 1020
# SUPPLIER_NAME: Infinity Supplies
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Bramfelder Str. 31, 22159 Hamburg, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Hamburg
# STOCK_QUANTITY: 200
# MANUFACTURER: Razer
# CITY_LAT: 53.550341
# CITY_LONG: 10.000654
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 21}
# ﻿PRODUCT_ID: P_0141
# PRODUCT_NAME: Corsair K95 RGB Platinum XT Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Corsair OPX Optical-Mechanical Keyswitches, 6 Key Rollover, RGB Backlighting, Dedicated Media Controls
# UNIT_PRICE: 209,99
# SUPPLIER_ID: 1021
# SUPPLIER_NAME: Hyper Semicon
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lange Str. 55, 80331 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 50
# MANUFACTURER: Corsair
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 22}
# ﻿PRODUCT_ID: P_0142
# PRODUCT_NAME: Apple Magic Mouse 2
# CATEGORY: IT Accessories
# DESCRIPTION: Rechargeable, Wireless Bluetooth Mouse with Multi-Touch Surface
# UNIT_PRICE: 89,99
# SUPPLIER_ID: 1022
# SUPPLIER_NAME: Neo Electronics
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Kupfergraben 10, 10178 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 350
# MANUFACTURER: Apple
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 23}
# ﻿PRODUCT_ID: P_0143
# PRODUCT_NAME: SteelSeries Arctis 7 Wireless Gaming Headset
# CATEGORY: IT Accessories
# DESCRIPTION: Lossless Wireless Audio, 24-Hour Battery Life, S1 Speaker Drivers, ClearCast Microphone
# UNIT_PRICE: 149,99
# SUPPLIER_ID: 1023
# SUPPLIER_NAME: Tech Dynamics
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Wankelstraße 14, 70563 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 300
# MANUFACTURER: SteelSeries
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 24}
# ﻿PRODUCT_ID: P_0144
# PRODUCT_NAME: Logitech G Pro X Superlight Wireless Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: HERO Sensor, Ultra-Lightweight Design, 5-Button Programmable, 25K DPI
# UNIT_PRICE: 129,99
# SUPPLIER_ID: 1024
# SUPPLIER_NAME: Electro Systems
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 50
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hauptstraße 45, 90762 Fürth, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Fürth
# STOCK_QUANTITY: 180
# MANUFACTURER: Logitech
# CITY_LAT: 49.48857105
# CITY_LONG: 10.95872031326412
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 25}
# ﻿PRODUCT_ID: P_0145
# PRODUCT_NAME: BenQ Zowie XL2411P 24 Inch Gaming Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: 144Hz Refresh Rate, 1ms Response Time, Black eQualizer, Adjustable Height
# UNIT_PRICE: 249,99
# SUPPLIER_ID: 1025
# SUPPLIER_NAME: Circuit Devices
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Friedrichstraße 25, 10117 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 250
# MANUFACTURER: BenQ
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 26}
# ﻿PRODUCT_ID: P_0146
# PRODUCT_NAME: Sennheiser Momentum 3 Wireless Headphones
# CATEGORY: IT Accessories
# DESCRIPTION: Active Noise Cancellation, 17-Hour Battery Life, High-Resolution Audio, Wireless & Wired Connection
# UNIT_PRICE: 379,99
# SUPPLIER_ID: 1026
# SUPPLIER_NAME: Volt Micro
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 12
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Am Borsigturm 1, 13507 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 90
# MANUFACTURER: Sennheiser
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 27}
# ﻿PRODUCT_ID: P_0147
# PRODUCT_NAME: Acer Predator X34P 34-Inch Curved Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: Curved 1800R, 120Hz Refresh Rate, NVIDIA G-SYNC, 21:9 UltraWide
# UNIT_PRICE: 699,99
# SUPPLIER_ID: 1027
# SUPPLIER_NAME: Byte Semicon
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Bruckstrasse 3, 80333 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 40
# MANUFACTURER: Acer
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 28}
# ﻿PRODUCT_ID: P_0148
# PRODUCT_NAME: Microsoft Surface Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Wireless Bluetooth, Precision Tracking, Slim Design, Available in Multiple Colors
# UNIT_PRICE: 54,99
# SUPPLIER_ID: 1028
# SUPPLIER_NAME: Fusion Devices
# LEAD_TIME_DAYS: 14
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Daimlerstraße 11, 70550 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 500
# MANUFACTURER: Microsoft
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 29}
# ﻿PRODUCT_ID: P_0149
# PRODUCT_NAME: Turtle Beach Stealth 700 Gen 2 Wireless Headset
# CATEGORY: IT Accessories
# DESCRIPTION: Surround Sound, 20-Hour Battery Life, Bluetooth Streaming, Active Noise Cancellation
# UNIT_PRICE: 179,99
# SUPPLIER_ID: 1029
# SUPPLIER_NAME: Circuit Parts
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 35
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Gustav-Freytag-Str. 2, 10555 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 150
# MANUFACTURER: Turtle Beach
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 30}
# ﻿PRODUCT_ID: P_0150
# PRODUCT_NAME: Kingston HyperX Alloy FPS Pro Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Tenkeyless Design, Red Mechanical Switches, RGB Backlighting
# UNIT_PRICE: 109,99
# SUPPLIER_ID: 1030
# SUPPLIER_NAME: Smart Networks
# LEAD_TIME_DAYS: 9
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: An der Kaimbrücke 9, 80331 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 200
# MANUFACTURER: Kingston
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 31}
# ﻿PRODUCT_ID: P_0151
# PRODUCT_NAME: Logitech C920 HD Pro Webcam
# CATEGORY: IT Accessories
# DESCRIPTION: Full HD 1080p, Autofocus, Stereo Audio, Plug & Play
# UNIT_PRICE: 99,99
# SUPPLIER_ID: 1031
# SUPPLIER_NAME: Fusion Components
# LEAD_TIME_DAYS: 11
# MIN_ORDER: 50
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Münchener Str. 12, 80337 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 320
# MANUFACTURER: Logitech
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 32}
# ﻿PRODUCT_ID: P_0152
# PRODUCT_NAME: Corsair Vengeance LPX 16GB (2 x 8GB) DDR4 RAM
# CATEGORY: IT Accessories
# DESCRIPTION: 3200MHz, 16GB Dual Channel Kit, High-Performance Memory
# UNIT_PRICE: 69,99
# SUPPLIER_ID: 1032
# SUPPLIER_NAME: Tech Electronics
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Zeppelinstr. 23, 30853 Langenhagen, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Langenhagen
# STOCK_QUANTITY: 180
# MANUFACTURER: Corsair
# CITY_LAT: 52.443118
# CITY_LONG: 9.738994
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 33}
# ﻿PRODUCT_ID: P_0153
# PRODUCT_NAME: Razer Kraken X Ultralight Gaming Headset
# CATEGORY: IT Accessories
# DESCRIPTION: 7.1 Surround Sound, 40mm Drivers, Lightweight Design, Adjustable Headband
# UNIT_PRICE: 49,99
# SUPPLIER_ID: 1033
# SUPPLIER_NAME: Smart Works
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Strassburger Str. 16, 76137 Karlsruhe, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Karlsruhe
# STOCK_QUANTITY: 350
# MANUFACTURER: Razer
# CITY_LAT: 49.0068705
# CITY_LONG: 8.4034195
# RATING: 3
# {'source': 'data/product_catalog.csv', 'row': 34}
# ﻿PRODUCT_ID: P_0154
# PRODUCT_NAME: Sony WH-1000XM4 Wireless Noise-Canceling Headphones
# CATEGORY: IT Accessories
# DESCRIPTION: Industry-Leading Noise Cancellation, 30-Hour Battery Life, Touch Sensor Controls
# UNIT_PRICE: 349,99
# SUPPLIER_ID: 1034
# SUPPLIER_NAME: Core Circuits
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Friedrichstr. 1, 10117 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 220
# MANUFACTURER: Sony
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 35}
# ﻿PRODUCT_ID: P_0155
# PRODUCT_NAME: HP Omen 15 Gaming Laptop
# CATEGORY: IT Accessories
# DESCRIPTION: Intel i7, 16GB RAM, 512GB SSD, 15.6” Full HD Display, NVIDIA GTX 1660 Ti
# UNIT_PRICE: 1,299,99
# SUPPLIER_ID: 1035
# SUPPLIER_NAME: Digital Devices
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Bismarckstraße 35, 10625 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 100
# MANUFACTURER: HP
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 36}
# ﻿PRODUCT_ID: P_0156
# PRODUCT_NAME: Samsung Odyssey G7 32-Inch Curved Gaming Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: 240Hz Refresh Rate, QHD Resolution, NVIDIA G-SYNC Compatible
# UNIT_PRICE: 799,99
# SUPPLIER_ID: 1036
# SUPPLIER_NAME: Core Group
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Sachsstraße 13, 01067 Dresden, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Dresden
# STOCK_QUANTITY: 60
# MANUFACTURER: Samsung
# CITY_LAT: 51.0493286
# CITY_LONG: 13.7381437
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 37}
# ﻿PRODUCT_ID: P_0157
# PRODUCT_NAME: Logitech G915 LIGHTSPEED Wireless RGB Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: RGB Backlighting, Low Profile Mechanical Switches, 30-Hour Battery Life, 5 Programmable Keys
# UNIT_PRICE: 229,99
# SUPPLIER_ID: 1037
# SUPPLIER_NAME: Crystal Circuits
# LEAD_TIME_DAYS: 9
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lindenstraße 20, 50933 Cologne, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Cologne
# STOCK_QUANTITY: 100
# MANUFACTURER: Logitech
# CITY_LAT: 43.7218277
# CITY_LONG: 0.9774958
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 38}
# ﻿PRODUCT_ID: P_0158
# PRODUCT_NAME: SteelSeries Rival 3 Wireless Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: AVAILABLEMove Air Optical Sensor, 18K DPI, 40 Hour Battery Life, RGB Lighting
# UNIT_PRICE: 59,99
# SUPPLIER_ID: 1038
# SUPPLIER_NAME: Nano Links
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Stuttgartstr. 24, 70173 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 250
# MANUFACTURER: SteelSeries
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 39}
# ﻿PRODUCT_ID: P_0159
# PRODUCT_NAME: Turtle Beach Recon 70 Wired Gaming Headset
# CATEGORY: IT Accessories
# DESCRIPTION: 40mm Speakers, Lightweight Design, High-Quality Mic, Compatible with PC, PS4, Xbox
# UNIT_PRICE: 39,99
# SUPPLIER_ID: 1039
# SUPPLIER_NAME: Crystal Systems
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 50
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Oststraße 14, 40211 Düsseldorf, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Düsseldorf
# STOCK_QUANTITY: 600
# MANUFACTURER: Turtle Beach
# CITY_LAT: 51.2254018
# CITY_LONG: 6.7763137
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 40}
# ﻿PRODUCT_ID: P_0160
# PRODUCT_NAME: HyperX Pulsefire FPS Pro RGB Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 16K DPI Sensor, RGB Lighting, 6 Programmable Buttons, Ergonomic Design
# UNIT_PRICE: 79,99
# SUPPLIER_ID: 1040
# SUPPLIER_NAME: Quantum Supplies
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Clemensstraße 4, 70197 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 350
# MANUFACTURER: HyperX
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 41}
# ﻿PRODUCT_ID: P_0161
# PRODUCT_NAME: Corsair K70 RGB MK.2 Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Cherry MX Keyswitches, RGB Backlighting, Aircraft-Grade Aluminum Frame, 8MB Profile Storage
# UNIT_PRICE: 169,99
# SUPPLIER_ID: 1041
# SUPPLIER_NAME: Blue Supplies
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Carl-Benz-Straße 1, 60528 Frankfurt, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 220
# MANUFACTURER: Corsair
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 42}
# ﻿PRODUCT_ID: P_0162
# PRODUCT_NAME: Razer BlackWidow V3 Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Razer Green Switches, RGB Chroma Backlighting, Dedicated Media Controls
# UNIT_PRICE: 119,99
# SUPPLIER_ID: 1042
# SUPPLIER_NAME: Fusion Dynamics
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Sonnenstraße 14, 80331 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 300
# MANUFACTURER: Razer
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 43}
# ﻿PRODUCT_ID: P_0163
# PRODUCT_NAME: Logitech G203 LIGHTSYNC RGB Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 8,000 DPI, 6 Programmable Buttons, LIGHTSYNC RGB Lighting, Classic Design
# UNIT_PRICE: 39,99
# SUPPLIER_ID: 1043
# SUPPLIER_NAME: Nano Devices
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Schwabenstraße 12, 85748 Garching, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Garching
# STOCK_QUANTITY: 450
# MANUFACTURER: Logitech
# CITY_LAT: 48.2513878
# CITY_LONG: 11.6509662
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 44}
# ﻿PRODUCT_ID: P_0164
# PRODUCT_NAME: MSI Optix MAG272C 27-Inch Curved Gaming Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: 165Hz Refresh Rate, 1ms Response Time, Full HD Curved Display, AMD FreeSync
# UNIT_PRICE: 299,99
# SUPPLIER_ID: 1044
# SUPPLIER_NAME: Byte Wave
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Siegstraße 5, 65812 Bad Soden, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Bad Soden
# STOCK_QUANTITY: 120
# MANUFACTURER: MSI
# CITY_LAT: 50.1517006
# CITY_LONG: 8.4899671
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 45}
# ﻿PRODUCT_ID: P_0165
# PRODUCT_NAME: Alienware AW2521H 25-Inch Gaming Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: 360Hz Refresh Rate, 1ms Response Time, NVIDIA G-SYNC, Full HD
# UNIT_PRICE: 549,99
# SUPPLIER_ID: 1045
# SUPPLIER_NAME: Optima Components
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hochstraße 4, 60313 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 180
# MANUFACTURER: Alienware
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 46}
# ﻿PRODUCT_ID: P_0166
# PRODUCT_NAME: Apple AirPods Pro 2nd Generation
# CATEGORY: IT Accessories
# DESCRIPTION: Active Noise Cancellation, Transparency Mode, Spatial Audio, Up to 6 Hours of Listening
# UNIT_PRICE: 249,99
# SUPPLIER_ID: 1046
# SUPPLIER_NAME: Crystal Labs
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Kaufingerstr. 11, 80331 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 350
# MANUFACTURER: Apple
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 47}
# ﻿PRODUCT_ID: P_0167
# PRODUCT_NAME: Bose QuietComfort 35 II Wireless Headphones
# CATEGORY: IT Accessories
# DESCRIPTION: Noise Cancelling, 20-Hour Battery Life, Bluetooth, Alexa Enabled
# UNIT_PRICE: 329,99
# SUPPLIER_ID: 1047
# SUPPLIER_NAME: Quantum Parts
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Marienplatz 9, 80331 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 200
# MANUFACTURER: Bose
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 48}
# ﻿PRODUCT_ID: P_0168
# PRODUCT_NAME: Logitech G Pro Wireless Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: Hero Sensor, 16,000 DPI, LIGHTSPEED Wireless Technology, Ultra-Lightweight
# UNIT_PRICE: 129,99
# SUPPLIER_ID: 1048
# SUPPLIER_NAME: Pixel Dynamics
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Oberlinden 13, 79539 Lörrach, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Lörrach
# STOCK_QUANTITY: 250
# MANUFACTURER: Logitech
# CITY_LAT: 47.6120896
# CITY_LONG: 7.6607218
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 49}
# ﻿PRODUCT_ID: P_0169
# PRODUCT_NAME: SteelSeries Apex Pro TKL Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: OmniPoint Adjustable Switches, RGB Backlighting, Aircraft-Grade Aluminum Alloy Frame
# UNIT_PRICE: 199,99
# SUPPLIER_ID: 1049
# SUPPLIER_NAME: Hyper Supplies
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Königsberger Str. 23, 70563 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 180
# MANUFACTURER: SteelSeries
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 50}
# ﻿PRODUCT_ID: P_0170
# PRODUCT_NAME: Corsair M65 RGB Elite Optical Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 18,000 DPI, 8 Programmable Buttons, Aluminum Frame, RGB Lighting
# UNIT_PRICE: 59,99
# SUPPLIER_ID: 1000
# SUPPLIER_NAME: Electro Semicon
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Maxstraße 12, 60311 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 300
# MANUFACTURER: Corsair
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 51}
# ﻿PRODUCT_ID: P_0171
# PRODUCT_NAME: HyperX Cloud II Wireless Gaming Headset
# CATEGORY: IT Accessories
# DESCRIPTION: 53mm Drivers, 7.1 Virtual Surround Sound, 30-Hour Battery Life, Detachable Microphone
# UNIT_PRICE: 149,99
# SUPPLIER_ID: 1001
# SUPPLIER_NAME: Electro Circuits
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Berliner Str. 9, 40210 Düsseldorf, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Düsseldorf
# STOCK_QUANTITY: 250
# MANUFACTURER: HyperX
# CITY_LAT: 51.2254018
# CITY_LONG: 6.7763137
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 52}
# ﻿PRODUCT_ID: P_0172
# PRODUCT_NAME: BenQ EW3270U 32-Inch 4K Monitor
# CATEGORY: IT Accessories
# DESCRIPTION: HDR, 95% DCI-P3, USB-C, 60Hz, IPS Panel
# UNIT_PRICE: 399,99
# SUPPLIER_ID: 1002
# SUPPLIER_NAME: Infinity Networks
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Mainzer Str. 10, 60325 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 140
# MANUFACTURER: BenQ
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 53}
# ﻿PRODUCT_ID: P_0173
# PRODUCT_NAME: SteelSeries Arctis Pro Wireless Gaming Headset
# CATEGORY: IT Accessories
# DESCRIPTION: Hi-Res Audio, Dual Wireless Technology, 20-Hour Battery Life, RGB Lighting
# UNIT_PRICE: 329,99
# SUPPLIER_ID: 1003
# SUPPLIER_NAME: Optima Networks
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Friedrichstraße 37, 70173 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 180
# MANUFACTURER: SteelSeries
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 54}
# ﻿PRODUCT_ID: P_0174
# PRODUCT_NAME: Razer DeathAdder Elite Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 16,000 DPI Optical Sensor, 7 Programmable Buttons, RGB Chroma Lighting, Ergonomic Shape
# UNIT_PRICE: 69,99
# SUPPLIER_ID: 1004
# SUPPLIER_NAME: Vertex Semicon
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Gewerbepark 25, 94518 Hauzenberg, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Hauzenberg
# STOCK_QUANTITY: 400
# MANUFACTURER: Razer
# CITY_LAT: 48.6551971
# CITY_LONG: 13.6276784
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 55}
# ﻿PRODUCT_ID: P_0175
# PRODUCT_NAME: Logitech G613 LIGHTSPEED Wireless Mechanical Gaming Keyboard
# CATEGORY: IT Accessories
# DESCRIPTION: Romber G Mechanical Keyswitches, 18-Hour Battery Life, LIGHTSPEED Wireless Technology
# UNIT_PRICE: 129,99
# SUPPLIER_ID: 1005
# SUPPLIER_NAME: Precision Dynamics
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 50
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Nordstraße 6, 80937 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 200
# MANUFACTURER: Logitech
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 56}
# ﻿PRODUCT_ID: P_0176
# PRODUCT_NAME: Samsung T7 Touch Portable SSD 1TB
# CATEGORY: IT Accessories
# DESCRIPTION: Fingerprint Security, 1050MB/s Read, 1000MB/s Write, USB 3.2 Gen 2
# UNIT_PRICE: 169,99
# SUPPLIER_ID: 1006
# SUPPLIER_NAME: Quantum Semicon
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Zeppelinstraße 9, 63477 Maintal, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Maintal
# STOCK_QUANTITY: 500
# MANUFACTURER: Samsung
# CITY_LAT: 50.1438711
# CITY_LONG: 8.8371266
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 57}
# ﻿PRODUCT_ID: P_0177
# PRODUCT_NAME: Seagate Expansion 4TB Portable Hard Drive
# CATEGORY: IT Accessories
# DESCRIPTION: Plug-and-Play, USB 3.0, 4TB Storage Capacity, Compact Design
# UNIT_PRICE: 119,99
# SUPPLIER_ID: 1007
# SUPPLIER_NAME: Hyper Labs
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Bachstraße 18, 74072 Heilbronn, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Heilbronn
# STOCK_QUANTITY: 300
# MANUFACTURER: Seagate
# CITY_LAT: 49.142291
# CITY_LONG: 9.218655
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 58}
# ﻿PRODUCT_ID: P_0178
# PRODUCT_NAME: ADATA XPG SX8200 Pro 1TB M.2 SSD
# CATEGORY: IT Accessories
# DESCRIPTION: Read Speed 3500MB/s, Write Speed 3000MB/s, PCIe Gen3x4, NVMe 1.3
# UNIT_PRICE: 129,99
# SUPPLIER_ID: 1008
# SUPPLIER_NAME: Digital Works
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Alte Landstraße 12, 20257 Hamburg, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Hamburg
# STOCK_QUANTITY: 200
# MANUFACTURER: ADATA
# CITY_LAT: 53.550341
# CITY_LONG: 10.000654
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 59}
# ﻿PRODUCT_ID: P_0179
# PRODUCT_NAME: Corsair Vengeance LPX 32GB (2 x 16GB) DDR4 RAM
# CATEGORY: IT Accessories
# DESCRIPTION: 3200MHz, 32GB Dual Channel Kit, High-Performance Memory
# UNIT_PRICE: 159,99
# SUPPLIER_ID: 1009
# SUPPLIER_NAME: Byte Works
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Schwanenstraße 8, 70173 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 250
# MANUFACTURER: Corsair
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 60}
# ﻿PRODUCT_ID: P_0180
# PRODUCT_NAME: HP Elite Dragonfly 13.3-inch Laptop
# CATEGORY: IT Accessories
# DESCRIPTION: Intel i5, 16GB RAM, 512GB SSD, 13.3” Full HD, Windows 10 Pro
# UNIT_PRICE: 1,499,99
# SUPPLIER_ID: 1010
# SUPPLIER_NAME: Circuit Micro
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Bismarckplatz 4, 80336 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 80
# MANUFACTURER: HP
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 61}
# ﻿PRODUCT_ID: P_0181
# PRODUCT_NAME: Lenovo ThinkPad X1 Carbon Gen 9
# CATEGORY: IT Accessories
# DESCRIPTION: Intel i7, 16GB RAM, 1TB SSD, 14” WQHD, Windows 10 Pro
# UNIT_PRICE: 2,299,99
# SUPPLIER_ID: 1011
# SUPPLIER_NAME: Logic Supplies
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Franzstraße 12, 44793 Bochum, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Bochum
# STOCK_QUANTITY: 100
# MANUFACTURER: Lenovo
# CITY_LAT: 51.4818111
# CITY_LONG: 7.2196635
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 62}
# ﻿PRODUCT_ID: P_0182
# PRODUCT_NAME: Asus ROG Strix G15 Gaming Laptop
# CATEGORY: IT Accessories
# DESCRIPTION: Intel i7, 16GB RAM, 512GB SSD, NVIDIA GTX 1660 Ti, 15.6” Full HD Display
# UNIT_PRICE: 1,299,99
# SUPPLIER_ID: 1012
# SUPPLIER_NAME: Neo Wave
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Thurn-und-Taxis-Platz 6, 60313 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 120
# MANUFACTURER: Asus
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 63}
# ﻿PRODUCT_ID: P_0183
# PRODUCT_NAME: MSI GE76 Raider 17.3-Inch Gaming Laptop
# CATEGORY: IT Accessories
# DESCRIPTION: Intel i9, 32GB RAM, 1TB SSD, NVIDIA RTX 3080, 17.3” Full HD Display
# UNIT_PRICE: 2,499,99
# SUPPLIER_ID: 1013
# SUPPLIER_NAME: Precision Links
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Münchener Str. 12, 80335 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 60
# MANUFACTURER: MSI
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 64}
# ﻿PRODUCT_ID: P_0184
# PRODUCT_NAME: Toshiba Canvio Basics 2TB Portable External Hard Drive
# CATEGORY: IT Accessories
# DESCRIPTION: USB 3.0, Plug-and-Play, 2TB Storage Capacity, Compact Design
# UNIT_PRICE: 69,99
# SUPPLIER_ID: 1014
# SUPPLIER_NAME: Neo Dynamics
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Schillerstraße 5, 80336 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 500
# MANUFACTURER: Toshiba
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 65}
# ﻿PRODUCT_ID: P_0185
# PRODUCT_NAME: Seagate BarraCuda 4TB Internal Hard Drive
# CATEGORY: IT Accessories
# DESCRIPTION: 5400RPM, SATA 6Gb/s, 4TB Storage Capacity, 256MB Cache
# UNIT_PRICE: 99,99
# SUPPLIER_ID: 1015
# SUPPLIER_NAME: Electro Industries
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hauptstraße 9, 70173 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 400
# MANUFACTURER: Seagate
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 66}
# ﻿PRODUCT_ID: P_0186
# PRODUCT_NAME: Western Digital My Passport 2TB Portable External Hard Drive
# CATEGORY: IT Accessories
# DESCRIPTION: USB 3.0, 2TB Storage Capacity, Plug-and-Play
# UNIT_PRICE: 79,99
# SUPPLIER_ID: 1016
# SUPPLIER_NAME: Volt Dynamics
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Friedrichstraße 24, 10117 Berlin, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Berlin
# STOCK_QUANTITY: 350
# MANUFACTURER: Western Digital
# CITY_LAT: 52.510885
# CITY_LONG: 13.3989367
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 67}
# ﻿PRODUCT_ID: P_0187
# PRODUCT_NAME: Logitech G923 Racing Wheel and Pedals
# CATEGORY: IT Accessories
# DESCRIPTION: AVAILABLEForce Force Feedback, Compatible with PlayStation, Xbox, and PC, Leather Wheel
# UNIT_PRICE: 399,99
# SUPPLIER_ID: 1017
# SUPPLIER_NAME: Optima Micro
# LEAD_TIME_DAYS: 7
# MIN_ORDER: 10
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hegelstraße 15, 70174 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 150
# MANUFACTURER: Logitech
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 68}
# ﻿PRODUCT_ID: P_0188
# PRODUCT_NAME: Thrustmaster T300 RS GT Racing Wheel
# CATEGORY: IT Accessories
# DESCRIPTION: HallEffect AccuRate Technology, Adjustable Force Feedback, Detachable GT Wheel
# UNIT_PRICE: 499,99
# SUPPLIER_ID: 1018
# SUPPLIER_NAME: Hyper Components
# LEAD_TIME_DAYS: 3
# MIN_ORDER: 25
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lindenstraße 4, 60325 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 180
# MANUFACTURER: Thrustmaster
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 69}
# ﻿PRODUCT_ID: P_0189
# PRODUCT_NAME: Hori Onyx Wireless Controller for PlayStation 4
# CATEGORY: IT Accessories
# DESCRIPTION: Bluetooth Wireless, 3.5mm Audio Jack, Customizable Buttons, Ergonomic Design
# UNIT_PRICE: 39,99
# SUPPLIER_ID: 1019
# SUPPLIER_NAME: Blue Components
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 40
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Hofstraße 12, 75323 Bad Wildbad, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Bad Wildbad
# STOCK_QUANTITY: 450
# MANUFACTURER: Hori
# CITY_LAT: 48.7502439
# CITY_LONG: 8.550301
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 70}
# ﻿PRODUCT_ID: P_0190
# PRODUCT_NAME: Razer Wolverine V2 Wired Gaming Controller
# CATEGORY: IT Accessories
# DESCRIPTION: Mecha-Tactile Action Buttons, Ergonomic Design, 6 Remappable Buttons
# UNIT_PRICE: 99,99
# SUPPLIER_ID: 1020
# SUPPLIER_NAME: Infinity Supplies
# LEAD_TIME_DAYS: 2
# MIN_ORDER: 30
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Weißer Stein 3, 60389 Frankfurt am Main, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Frankfurt
# STOCK_QUANTITY: 200
# MANUFACTURER: Razer
# CITY_LAT: 50.1106444
# CITY_LONG: 8.6820917
# RATING: 5
# {'source': 'data/product_catalog.csv', 'row': 71}
# ﻿PRODUCT_ID: P_0191
# PRODUCT_NAME: PDP Afterglow Wireless Deluxe Controller
# CATEGORY: IT Accessories
# DESCRIPTION: RGB LED Lighting, Bluetooth Wireless, Ergonomic Design, Compatible with PC and Xbox One
# UNIT_PRICE: 59,99
# SUPPLIER_ID: 1021
# SUPPLIER_NAME: Hyper Semicon
# LEAD_TIME_DAYS: 6
# MIN_ORDER: 35
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Münchener Str. 8, 80336 Munich, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Munich
# STOCK_QUANTITY: 300
# MANUFACTURER: PDP
# CITY_LAT: 48.1371079
# CITY_LONG: 11.5753822
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 72}
# ﻿PRODUCT_ID: P_0192
# PRODUCT_NAME: SteelSeries Rival 110 Gaming Mouse
# CATEGORY: IT Accessories
# DESCRIPTION: 6,000 DPI, RGB Lighting, Ergonomic Design, Durable Construction
# UNIT_PRICE: 39,99
# SUPPLIER_ID: 1022
# SUPPLIER_NAME: Neo Electronics
# LEAD_TIME_DAYS: 4
# MIN_ORDER: 50
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Lindenstr. 8, 70191 Stuttgart, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Stuttgart
# STOCK_QUANTITY: 400
# MANUFACTURER: SteelSeries
# CITY_LAT: 48.7784485
# CITY_LONG: 9.1800132
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 73}
# ﻿PRODUCT_ID: P_0193
# PRODUCT_NAME: Nacon Revolution Unlimited Pro Controller
# CATEGORY: IT Accessories
# DESCRIPTION: Precision Control, Adjustable Weight, Dual Shock Vibration, Compatible with PC and PS4
# UNIT_PRICE: 129,99
# SUPPLIER_ID: 1023
# SUPPLIER_NAME: Tech Dynamics
# LEAD_TIME_DAYS: 5
# MIN_ORDER: 20
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Leipziger Str. 20, 40470 Düsseldorf, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Düsseldorf
# STOCK_QUANTITY: 350
# MANUFACTURER: Nacon
# CITY_LAT: 51.2254018
# CITY_LONG: 6.7763137
# RATING: 4
# {'source': 'data/product_catalog.csv', 'row': 74}
# ﻿PRODUCT_ID: P_0194
# PRODUCT_NAME: Thrustmaster T150 Pro Racing Wheel
# CATEGORY: IT Accessories
# DESCRIPTION: HallEffect AccuRate Technology, Adjustable Force Feedback, Detachable GT Wheel
# UNIT_PRICE: 249,99
# SUPPLIER_ID: 1024
# SUPPLIER_NAME: Electro Systems
# LEAD_TIME_DAYS: 8
# MIN_ORDER: 15
# CURRENCY: EURO
# SUPPLIER_COUNTRY: Germany
# SUPPLIER_ADDRESS: Gutenbergstraße 9, 40880 Düsseldorf, Germany
# STATUS: AVAILABLE
# SUPPLIER_CITY: Düsseldorf
# STOCK_QUANTITY: 180
# MANUFACTURER: Thrustmaster
# CITY_LAT: 51.2254018
# CITY_LONG: 6.7763137
# RATING: 5

# %% [markdown]
# > At this point we have implemented the first RAG step - generated text chunks from source data
# >
# > ![rag_indexing_1](./images/rag_indexing_1.png)

# %% [markdown]
# ### SAP HANA Cloud vector engine
#
# Storing vector embeddings within the same database is a strategic move that aligns seamlessly with SAP's commitment to providing a unified platform. This integration eliminates the hurdles posed by data silos, offering a holistic approach to data management. In SAP HANA Cloud, the storage of vector embeddings is seamlessly integrated into the platform's existing structure, allowing users to store them in a designated table. Developers can perform SQL-like queries effortlessly.
#
# This means you can execute joins, apply filters, and perform selects by combining vector embeddings with various data types, including transactional, spatial, graph, and JSON data, all within the same SQL environment. The Vector Engine ensures a user-friendly experience, eliminating the need for extensive learning or the adoption of new querying methodologies. Essentially, working with vector embeddings in SAP HANA Cloud is as straightforward as crafting queries in a standard SQL database, offering familiarity and ease of use for developers.

# %% [markdown]
# #### Connect to the HANA vector storage instance
#
# The provided Python script imports database connection modules and initiates a connection to a SAP HANA Cloud instance using the `dbapi` module. The user is prompted to enter their username and password, which are then used to establish a secure connection to the SAP HANA Cloud database.

# %%
# HC Vector Engine
import os
from hdbcli import dbapi

# Load HANA Cloud connection details
with open(os.path.join(os.getcwd(), 'env_cloud.json')) as f:
    hana_env_c = json.load(f)

# Establish a connection to the HANA Cloud database
connection = dbapi.connect( 
    address=hana_env_c['url'],
    port=hana_env_c['port'], 
    user=hana_env_c['user'], 
    password=hana_env_c['pwd']   
)

# %% [markdown]
# ## Generate and store embeddings in SAP HANA Cloud
#
# We will be using two types of Embedding Models to generate the embeddings: **text-embedding-3-large** from OpenAI and **SAP_GXY.20250407** from SAP.

# %% [markdown]
# ### Initialize the OpenAI embedding model
# Embeddings are vector representations of text data that incorporate the semantic meaning of the text. Define the embeddings object that generates embeddings from text data using the **text-embedding-3-large** model. This function will be used to generate embeddings from the user's prompts.

# %%
# harmonized init helper
from gen_ai_hub.proxy.langchain.init_models import init_embedding_model
open_ai_embedding_model = init_embedding_model('text-embedding-3-large', proxy_client=proxy_client)

# %% [markdown]
# ### Test the OpenAI embedding model

# %%
# Input string
text = "SAP Generative AI Hub is awesome!"
# Generate the embedding
embedding = open_ai_embedding_model.embed_query(text)
print(embedding)
# Out:
# %% [markdown]
# ### Populate the table with data and create a REAL_VECTOR column to store embeddings
#
# Create a LangChain VectorStore interface for the HANA database and specify the table (collection) to use for accessing the vector embeddings. Embeddings are vector representations of text data that incorporate the semantic meaning of the text.
#
# The `langchain_hana` library, specifically the `HanaDB` class, from the LangChain community, enables interaction with SAP HANA Cloud's vector storage capabilities. It provides tools to manage and query vector embeddings stored in SAP HANA Cloud, making it easier to implement workflows like Retrieval Augmented Generation (RAG) using SAP HANA's advanced database features.

# %%
from langchain_hana import HanaDB
# Create a LangChain VectorStore interface for the HANA database and specify the table (collection) to use for accessing the vector embeddings
db_openai_table = HanaDB(
    embedding=open_ai_embedding_model, 
    connection=connection, 
    table_name="PRODUCTS_IT_ACCESSORY_OPENAI_"+ hana_env_c['user'],
    content_column="VEC_TEXT", # the original text description of the product details
    metadata_column="VEC_META", # metadata associated with the product details
    vector_column="VEC_VECTOR" # the vector representation of each product 
)

# %%
# Delete already existing documents from the table
db_openai_table.delete(filter={})

# add the loaded document chunks
db_openai_table.add_documents(text_chunks)
# Out:
# []

# %% [markdown]
# ### Verify product embeddings in SAP HANA Cloud

# %%
# Query the table to verify embeddings
cursor = connection.cursor()
sql = f'SELECT VEC_TEXT, TO_NVARCHAR(VEC_VECTOR) FROM "{db_openai_table.table_name}"'

cursor.execute(sql)
vectors = cursor.fetchall()

for vector in vectors:
    print(vector)
# Out:
# ('PRODUCT_ID: P_0110\nPRODUCT_NAME: Logitech Signature M650 L Full Size Wireless Mouse\nCATEGORY: IT Accessories\nDESCRIPTION: Scroll smarter: With Logitech Signature M650 Wireless Mouse you get line-by-line precision for documents and super-fast scrolling for long web pages\nUNIT_PRICE: 34,75\nSUPPLIER_ID: 1000\nSUPPLIER_NAME: Electro Semicon\nLEAD_TIME_DAYS: 13\nMIN_ORDER: 32\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Holzhausenstraße 6, 60318 Frankfurt am Main, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Frankfurt\nSTOCK_QUANTITY: 104\nMANUFACTURER: Logitech\nCITY_LAT: 50.1106444\nCITY_LONG: 8.6820917\nRATING: 5', '[-0.039591722,0.0048316913,-0.009679019,0.018028932,-0.019154763,-0.035432402,-0.0049763294,0.053226788,-0.0040537734,0.012431051,0.000566336,-0.03846589,0.02125006,-0.021687882,0.004440778,-0.016731098,-0.030819623,-0.020374414,-0.03155454,-0.003629632,0.04131174,-0.007947272,0.00085952115,0.016965648,-0.023548631,-0.009108285,-0.009170831,0.014839077,0.033118196,0.02120315,-0.009311561,0.014229253,-0.008334276,-0.0036960875,0.018388573,-0.016465278,0.010077751,-0.004128047,0.082811125,0.04909874,0.02115624,0.0048004184,-0.021234423,-0.0063406173,-0.025941022,0.049911838,0.0046323254,0.008912829,-0.027817408,-0.028724326,-0.0071498086,-0.019874044,-0.088815555,-0.011547586,0.0017434744,-0.01967077,0.034244027,0.10695394,0.024424277,0.015527085,-0.017606746,-0.024033364,-0.01967077,-0.032211274,-0.007849543,0.019060943,-0.019217309,0.011899408,0.027457766
026843792,0.027466891,-0.040450934,0.0067277886,-0.022178968,-0.053586543,-0.009093882,0.0071067004,0.027685817,0.010803195,0.051868808,0.0037112301,0.016225843,-0.018373009,-0.015038586,0.014945963,0.019972859,0.00012748802,0.02450296,-0.013514519,0.041090872,0.025227102,0.0049174326,-0.009775923,-0.0041364534,-0.0059152334,0.013388215,0.027500572,-0.032704294,0.0027260594,0.0126977535,0.033714727,0.03256957,-0.0013998684,-0.02197688,0.010542166,0.045065235,0.016933145,0.01515647,0.011855727,0.012015712,0.05459697,0.04200026,0.015670106,0.019821294,0.031441256,0.016680537,-0.0032375904,0.022852588,0.025631275,0.034657795,0.036038715,0.0061467905,-0.027433211,0.02317256,-0.03322635,-0.03389997,0.0012030448,-0.041528728,0.00037496476,0.020595958,0.008799173,0.0018629828,-0.012975622,-0.03448939,-0.013000883,-0.008967578,-0.026995357,-0.02258314,0.006938295,-0.010718992,0.029066741,-0.017261535,-0.012285161,0.0026313316,-0.01225148,0.004450108,0.0050521567,-0.0069509256,-0.020158105,0.014861761,0.020528596,0.013783967,-0.0017408889,-0.039608907,-0.022515777,-0.016183741,0.052171938,0.021808475,0.018238286,0.03196331,0.00306287,0.024081947,-0.004161714,-0.020747524,0.027904745,-0.03583663,0.033883132,-0.02199372,0.024974493,0.030413983,-0.03863216,0.0036838641,-0.034017853,0.009582257,-0.018642457,0.016394248,-0.02645646,0.020781204,-0.0001976 ...

# %% [markdown]
# > At this point we have implemented the Indexing Process part of RAG
# >
# > ![rag_indexing_2](./images/rag_indexing_2.png)

# %% [markdown]
# ## Performing a Vector Search to Find Relevant Products
#
# ## Vector Search Using OpenAI's Embedding Model (*text-embedding-3-large*)
#
# In this step, we use the **text-embedding-3-large** model to convert a natural language query into a vector representation and retrieve the most relevant records from a database using **vector similarity search**.

# %%
# Define the Query 
question = "Suggest a keyboard with a rating 4 or more"
# Using an embedding model (text-embedding-3-large), we transform the text query into a numerical vector:
query_vector = open_ai_embedding_model.embed_query(question)

# We construct an SQL query that retrieves the top 10 most relevant records based on cosine similarity:
#       COSINE_SIMILARITY: Measures how similar two vectors are. A higher value means a better match.
#       TO_REAL_VECTOR('{qv}'): Converts the query vector into the correct SQL-compatible format.
#       ORDER BY COSINE_SIMILARITY DESC: Ensures that the best matches appear at the top.
sql_vector_search_openai = '''SELECT TOP {k}  VEC_TEXT, "{metric}"("VEC_VECTOR", TO_REAL_VECTOR('{qv}')) as SCORING
        FROM {table}
        ORDER BY "{metric}"("VEC_VECTOR", TO_REAL_VECTOR('{qv}')) {sort}'''.format(k=10, metric="COSINE_SIMILARITY", qv=query_vector, table=db_openai_table.table_name, sort="DESC")

# We execute the SQL statement using the database cursor. This fetches the top 10 relevant results based on vector similarity.
cursor.execute(sql_vector_search_openai)
vectors = cursor.fetchall()

#  we iterate over the retrieved results and print them:
for vector in vectors:
    print(vector)
# Out:
# ('PRODUCT_ID: P_0129\nPRODUCT_NAME: Arteck Split Ergonomic Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Arteck Split Ergonomic Keyboard with Cushioned Wrist and Palm Rest, 2.4G USB Wireless Comfortable Natural Ergonomic Split Keyboard\nUNIT_PRICE: 246,11\nSUPPLIER_ID: 1005\nSUPPLIER_NAME: Precision Dynamics\nLEAD_TIME_DAYS: 11\nMIN_ORDER: 26\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Otto-Hahn-Straße 12, 44227 Dortmund, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 768\nMANUFACTURER: Arteck\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 4', 0.4482539563330394)
# ('PRODUCT_ID: P_0117\nPRODUCT_NAME: Kensington Pro Fit Ergonomic Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Kensington Pro Fit Ergo Wireless Keyboard, QWERTY keyboard layout, Dual 2.4 GHz and Bluetooth 4.2 technology\nUNIT_PRICE: 239,18\nSUPPLIER_ID: 1014\nSUPPLIER_NAME: Neo Dynamics\nLEAD_TIME_DAYS: 1\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lange Str. 62, 44137 Dortmund, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 808\nMANUFACTURER: Kensington\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 3', 0.42077246780559685)
# ('PRODUCT_ID: P_0118\nPRODUCT_NAME: Logitech ERGO K860\nCATEGORY: IT Accessories\nDESCRIPTION: Logitech ERGO K860 Wireless Ergonomic Keyboard\nUNIT_PRICE: 239,18\nSUPPLIER_ID: 1004\nSUPPLIER_NAME: Vertex Semicon\nLEAD_TIME_DAYS: 1\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lange Str. 62, 44137 Dortmund, Germany\nSTATUS: NOT AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 0\nMANUFACTURER: Logitec\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 4', 0.41498575121249326)
# ('PRODUCT_ID: P_0141\nPRODUCT_NAME: Corsair K95 RGB Platinum XT Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Corsair OPX Optical-Mechanical Keyswitches, 6 Key Rollover, RGB Backlighting, Dedicated Media Controls\nUNIT_PRICE: 209,99\nSUPPLIER_ID: 1021\nSUPPLIER_NAME: Hyper Semicon\nLEAD_TIME_DAYS: 5\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lange Str. 55, 80331 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 50\nMANUFACTURER: Corsair\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 4', 0.4077216386795044)
# ('PRODUCT_ID: P_0128\nPRODUCT_NAME: Microsoft L5V-00006 Sculpt Ergonomic Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Microsoft L5V-00006 Sculpt Ergonomic Desktop Keyboard\nUNIT_PRICE: 246,11\nSUPPLIER_ID: 1015\nSUPPLIER_NAME: Electro Industries\nLEAD_TIME_DAYS: 11\nMIN_ORDER: 26\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Otto-Hahn-Straße 12, 44227 Dortmund, Germany\nSTATUS: NOT AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 0\nMANUFACTURER: Microsoft\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 4', 0.4024150193457313)
# ('PRODUCT_ID: P_0175\nPRODUCT_NAME: Logitech G613 LIGHTSPEED Wireless Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Romber G Mechanical Keyswitches, 18-Hour Battery Life, LIGHTSPEED Wireless Technology\nUNIT_PRICE: 129,99\nSUPPLIER_ID: 1005\nSUPPLIER_NAME: Precision Dynamics\nLEAD_TIME_DAYS: 2\nMIN_ORDER: 50\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Nordstraße 6, 80937 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 200\nMANUFACTURER: Logitech\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 4', 0.3966408906364979)
# ('PRODUCT_ID: P_0157\nPRODUCT_NAME: Logitech G915 LIGHTSPEED Wireless RGB Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: RGB Backlighting, Low Profile Mechanical Switches, 30-Hour Battery Life, 5 Programmable Keys\nUNIT_PRICE: 229,99\nSUPPLIER_ID: 1037\nSUPPLIER_NAME: Crystal Circuits\nLEAD_TIME_DAYS: 9\nMIN_ORDER: 40\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lindenstraße 20, 50933 Cologne, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Cologne\nSTOCK_QUANTITY: 100\nMANUFACTURER: Logitech\nCITY_LAT: 43.7218277\nCITY_LONG: 0.9774958\nRATING: 5', 0.39246435142947306)
# ('PRODUCT_ID: P_0150\nPRODUCT_NAME: Kingston HyperX Alloy FPS Pro Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Tenkeyless Design, Red Mechanical Switches, RGB Backlighting\nUNIT_PRICE: 109,99\nSUPPLIER_ID: 1030\nSUPPLIER_NAME: Smart Networks\nLEAD_TIME_DAYS: 9\nMIN_ORDER: 15\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: An der Kaimbrücke 9, 80331 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 200\nMANUFACTURER: Kingston\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 4', 0.3919311528246915)
# ('PRODUCT_ID: P_0161\nPRODUCT_NAME: Corsair K70 RGB MK.2 Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Cherry MX Keyswitches, RGB Backlighting, Aircraft-Grade Aluminum Frame, 8MB Profile Storage\nUNIT_PRICE: 169,99\nSUPPLIER_ID: 1041\nSUPPLIER_NAME: Blue Supplies\nLEAD_TIME_DAYS: 4\nMIN_ORDER: 20\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Carl-Benz-Straße 1, 60528 Frankfurt, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Frankfurt\nSTOCK_QUANTITY: 220\nMANUFACTURER: Corsair\nCITY_LAT: 50.1106444\nCITY_LONG: 8.6820917\nRATING: 5', 0.3839083955206048)
# ('PRODUCT_ID: P_0162\nPRODUCT_NAME: Razer BlackWidow V3 Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Razer Green Switches, RGB Chroma Backlighting, Dedicated Media Controls\nUNIT_PRICE: 119,99\nSUPPLIER_ID: 1042\nSUPPLIER_NAME: Fusion Dynamics\nLEAD_TIME_DAYS: 2\nMIN_ORDER: 30\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Sonnenstraße 14, 80331 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 300\nMANUFACTURER: Razer\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 5', 0.37664649625739544)

# %% [markdown]
# ## Vector Search Using SAP's Embedding Model (*SAP_GXY.20250407*)
#
# You will:
#
# 1. **Create a table** in SAP HANA to store text data and generate vector embeddings using **SAP_GXY.20250407**.
# 2. **Insert product descriptions** into the table, allowing automatic embedding generation.
# 3. **Perform a vector search** to retrieve the most relevant products based on semantic similarity.

# %% [markdown]
# ### Creating a table with automatic vector embeddings

# %%
from langchain_hana import HanaInternalEmbeddings

# HANA-internal embedding
internal_emb = HanaInternalEmbeddings(internal_embedding_model_id="SAP_GXY.20250407")

db_internal_emb_table = HanaDB(
    embedding=internal_emb, 
    connection=connection, 
    table_name="PRODUCTS_IT_ACCESSORY_SAP_"+ hana_env_c['user'],
    content_column="VEC_TEXT", # the original text description of the product details
    metadata_column="VEC_META", # metadata associated with the product details
    vector_column="VEC_VECTOR" # the vector representation of each product 
)

# %% [markdown]
# ### Inserting data in SAP HANA Cloud

# %%
# Delete already existing documents from the table
db_internal_emb_table.delete(filter={})

# add the loaded document chunks
db_internal_emb_table.add_documents(text_chunks)
# Out:
# []

# %% [markdown]
# ### Querying the table to verify stored embeddings

# %%
# Query the table to verify embeddings
cursor = connection.cursor()
sql = f'SELECT VEC_TEXT, TO_NVARCHAR(VEC_VECTOR) FROM "{db_internal_emb_table.table_name}"'

cursor.execute(sql)
vectors = cursor.fetchall()

for vector in vectors:
    print(vector)
# Out:
# ('PRODUCT_ID: P_0110\nPRODUCT_NAME: Logitech Signature M650 L Full Size Wireless Mouse\nCATEGORY: IT Accessories\nDESCRIPTION:
# %% [markdown]
# ### Perform a vector search using SAP's embedding model
#
# We convert a natural language query into a vector and find the most relevant results using cosine similarity.
#
# * `VECTOR_EMBEDDING('{question}', 'QUERY', 'SAP_GXY.20250407')` converts the search query into a vector.
# * `COSINE_SIMILARITY(..., VEC_VECTOR)` computes similarity scores between the query and stored embeddings.
# * `ORDER BY DESC` ensures the most relevant results appear at the top.

# %%
question = "Suggest a keyboard with a rating 4 or more"

# Using an internal SAP HANA embedding model SAP_GXY.20250407 we transform the text query into a numerical vector:
vector_function_sql = f"COSINE_SIMILARITY(VECTOR_EMBEDDING('{question}', 'QUERY', 'SAP_GXY.20250407'), VEC_VECTOR)"

# We construct an SQL query that retrieves the top 10 most relevant records based on cosine similarity:
sql_vector_search_sap = '''SELECT TOP {k} VEC_TEXT, {metric} as SCORING
        FROM {table}
        ORDER BY {metric} {sort}'''.format(k=10, metric=vector_function_sql, table=db_internal_emb_table.table_name, sort="DESC")

cursor.execute(sql_vector_search_sap)
output_suggestion_sap_model = cursor.fetchall()

# Convert to a readable JSON format.
output_suggestion_sap_model_json = json.dumps([
            {"text":item[0], "score":item[1]}
            for item in output_suggestion_sap_model
        ], indent=4)

print(output_suggestion_sap_model_json)
# Out:
# [
#     {
#         "text": "PRODUCT_ID: P_0117\nPRODUCT_NAME: Kensington Pro Fit Ergonomic Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Kensington Pro Fit Ergo Wireless Keyboard, QWERTY keyboard layout, Dual 2.4 GHz and Bluetooth 4.2 technology\nUNIT_PRICE: 239,18\nSUPPLIER_ID: 1014\nSUPPLIER_NAME: Neo Dynamics\nLEAD_TIME_DAYS: 1\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lange Str. 62, 44137 Dortmund, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 808\nMANUFACTURER: Kensington\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 3",
#         "score": 0.5108635366971471
#     },
#     {
#         "text": "PRODUCT_ID: P_0161\nPRODUCT_NAME: Corsair K70 RGB MK.2 Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Cherry MX Keyswitches, RGB Backlighting, Aircraft-Grade Aluminum Frame, 8MB Profile Storage\nUNIT_PRICE: 169,99\nSUPPLIER_ID: 1041\nSUPPLIER_NAME: Blue Supplies\nLEAD_TIME_DAYS: 4\nMIN_ORDER: 20\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Carl-Benz-Stra\u00dfe 1, 60528 Frankfurt, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Frankfurt\nSTOCK_QUANTITY: 220\nMANUFACTURER: Corsair\nCITY_LAT: 50.1106444\nCITY_LONG: 8.6820917\nRATING: 5",
#         "score": 0.5091040720421627
#     },
#     {
#         "text": "PRODUCT_ID: P_0189\nPRODUCT_NAME: Hori Onyx Wireless Controller for PlayStation 4\nCATEGORY: IT Accessories\nDESCRIPTION: Bluetooth Wireless, 3.5mm Audio Jack, Customizable Buttons, Ergonomic Design\nUNIT_PRICE: 39,99\nSUPPLIER_ID: 1019\nSUPPLIER_NAME: Blue Components\nLEAD_TIME_DAYS: 5\nMIN_ORDER: 40\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Hofstra\u00dfe 12, 75323 Bad Wildbad, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Bad Wildbad\nSTOCK_QUANTITY: 450\nMANUFACTURER: Hori\nCITY_LAT: 48.7502439\nCITY_LONG: 8.550301\nRATING: 4",
#         "score": 0.49956895174361093
#     },
#     {
#         "text": "PRODUCT_ID: P_0153\nPRODUCT_NAME: Razer Kraken X Ultralight Gaming Headset\nCATEGORY: IT Accessories\nDESCRIPTION: 7.1 Surround Sound, 40mm Drivers, Lightweight Design, Adjustable Headband\nUNIT_PRICE: 49,99\nSUPPLIER_ID: 1033\nSUPPLIER_NAME: Smart Works\nLEAD_TIME_DAYS: 3\nMIN_ORDER: 40\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Strassburger Str. 16, 76137 Karlsruhe, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Karlsruhe\nSTOCK_QUANTITY: 350\nMANUFACTURER: Razer\nCITY_LAT: 49.0068705\nCITY_LONG: 8.4034195\nRATING: 3",
#         "score": 0.49757906577419747
#     },
#     {
#         "text": "PRODUCT_ID: P_0129\nPRODUCT_NAME: Arteck Split Ergonomic Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Arteck Split Ergonomic Keyboard with Cushioned Wrist and Palm Rest, 2.4G USB Wireless Comfortable Natural Ergonomic Split Keyboard\nUNIT_PRICE: 246,11\nSUPPLIER_ID: 1005\nSUPPLIER_NAME: Precision Dynamics\nLEAD_TIME_DAYS: 11\nMIN_ORDER: 26\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Otto-Hahn-Stra\u00dfe 12, 44227 Dortmund, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Dortmund\nSTOCK_QUANTITY: 768\nMANUFACTURER: Arteck\nCITY_LAT: 51.5142273\nCITY_LONG: 7.4652789\nRATING: 4",
#         "score": 0.49536400531809976
#     },
#     {
#         "text": "PRODUCT_ID: P_0111\nPRODUCT_NAME: UGREEN 2.4G Wireless Mouse\nCATEGORY: IT Accessories\nDESCRIPTION: Laptop, 4000 DPI 5 Adjustable Levels Ergonomic USB Wireless Mouse Compatible With PC MacBook Chromebook, 18-Month Battery Life (Black)\nUNIT_PRICE: 34,75\nSUPPLIER_ID: 1010\nSUPPLIER_NAME: Circuit Micro\nLEAD_TIME_DAYS: 13\nMIN_ORDER: 32\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Holzhausenstra\u00dfe 6, 60318 Frankfurt am Main, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Frankfurt\nSTOCK_QUANTITY: 104\nMANUFACTURER: UGREEN\nCITY_LAT: 50.1106444\nCITY_LONG: 8.6820917\nRATING: 3",
#         "score": 0.4950923142455031
#     },
#     {
#         "text": "PRODUCT_ID: P_0169\nPRODUCT_NAME: SteelSeries Apex Pro TKL Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: OmniPoint Adjustable Switches, RGB Backlighting, Aircraft-Grade Aluminum Alloy Frame\nUNIT_PRICE: 199,99\nSUPPLIER_ID: 1049\nSUPPLIER_NAME: Hyper Supplies\nLEAD_TIME_DAYS: 8\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: K\u00f6nigsberger Str. 23, 70563 Stuttgart, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Stuttgart\nSTOCK_QUANTITY: 180\nMANUFACTURER: SteelSeries\nCITY_LAT: 48.7784485\nCITY_LONG: 9.1800132\nRATING: 5",
#         "score": 0.4923992032693086
#     },
#     {
#         "text": "PRODUCT_ID: P_0141\nPRODUCT_NAME: Corsair K95 RGB Platinum XT Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Corsair OPX Optical-Mechanical Keyswitches, 6 Key Rollover, RGB Backlighting, Dedicated Media Controls\nUNIT_PRICE: 209,99\nSUPPLIER_ID: 1021\nSUPPLIER_NAME: Hyper Semicon\nLEAD_TIME_DAYS: 5\nMIN_ORDER: 10\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Lange Str. 55, 80331 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 50\nMANUFACTURER: Corsair\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 4",
#         "score": 0.4922801349365895
#     },
#     {
#         "text": "PRODUCT_ID: P_0150\nPRODUCT_NAME: Kingston HyperX Alloy FPS Pro Mechanical Gaming Keyboard\nCATEGORY: IT Accessories\nDESCRIPTION: Tenkeyless Design, Red Mechanical Switches, RGB Backlighting\nUNIT_PRICE: 109,99\nSUPPLIER_ID: 1030\nSUPPLIER_NAME: Smart Networks\nLEAD_TIME_DAYS: 9\nMIN_ORDER: 15\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: An der Kaimbr\u00fccke 9, 80331 Munich, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Munich\nSTOCK_QUANTITY: 200\nMANUFACTURER: Kingston\nCITY_LAT: 48.1371079\nCITY_LONG: 11.5753822\nRATING: 4",
#         "score": 0.48551818190020946
#     },
#     {
#         "text": "PRODUCT_ID: P_0123\nPRODUCT_NAME: TECKNET Wireless Mouse for Laptop\nCATEGORY: IT Accessories\nDESCRIPTION: 4800 DPI Optical Computer Mice with 6 Adjustable Levels, 30 Months Long Battery Life 2.4G Cordless USB Silent Mouse for Notebook, PC, Office Home Work (Grey)\nUNIT_PRICE: 272,09\nSUPPLIER_ID: 1006\nSUPPLIER_NAME: Quantum Semicon\nLEAD_TIME_DAYS: 8\nMIN_ORDER: 33\nCURRENCY: EURO\nSUPPLIER_COUNTRY: Germany\nSUPPLIER_ADDRESS: Eschborner Landstra\u00dfe 55, 60489 Frankfurt am Main, Germany\nSTATUS: AVAILABLE\nSUPPLIER_CITY: Frankfurt\nSTOCK_QUANTITY: 221\nMANUFACTURER: TECKNET\nCITY_LAT: 50.1106444\nCITY_LONG: 8.6820917\nRATING: 2",
#         "score": 0.4851778776494668
#     }
# ]

# %% [markdown]
# > At this point we have successfully implemented the first step of Retrieval Process and enabled semantic vector similarity search to **retrieve relevant results from SAP HANA Cloud** based on user question.
# >
# > ![rag_retrieval_1](./images/rag_retrieval_1.png)

# %% [markdown]
# ## Enhancing Query Responses by Passing Context and Prompt to LLM
#
# ### Define a prompt template to provide context to queries
#
# Define a prompt template to provide context to our prompts. Thus, when passed to the model, the template will add the necessary context to the prompt so that more accurate results are generated.
#
# The answer should contain the requested information about products and their descriptions, formatted according to the specified JSON structure for further use in the SAP HANA JSON Document store.
#
# > The created template for the prompt contains two variables - **context** and **question**. These variables will be replaced with the context and question in the upcoming steps.

# %%
from langchain_core.prompts import PromptTemplate
from textwrap import dedent

# Define the custom prompt
prompt_template = PromptTemplate(
    input_variables=["context", "input"],
    template=dedent("""
        Use the following pieces of context to answer the question at the end. 
        If you don't know the answer, just say you don't know. Do not make up an answer.

        Format the results as a list of JSON items with these keys:
            - "PRODUCT_ID"
            - "PRODUCT_NAME"
            - "CATEGORY"
            - "DESCRIPTION"
            - "UNIT_PRICE"
            - "SUPPLIER_ID"
            - "SUPPLIER_NAME"
            - "LEAD_TIME_DAYS"
            - "MIN_ORDER"
            - "CURRENCY"
            - "SUPPLIER_COUNTRY"
            - "SUPPLIER_ADDRESS"
            - "STATUS"
            - "SUPPLIER_CITY"
            - "STOCK_QUANTITY"
            - "MANUFACTURER"
            - "RATING"

        Note:
            - The 'RATING' must be an integer from 0 (bad) to 5 (excellent).
            - Do not include markdown or code blocks like ```json.

        {context}

        Question: {input}
    """)
)

# %% [markdown]
# ### Create the Conversational Retrieval Chain with SAP HANA Cloud vector engine
#
#
# This code snippet integrates various components from the `langchain` library to create a retrieval-based question-answering (QA) system. Here's a breakdown of the key parts and their functionality:
#
# - **Retriever Initialization:** The `db_openai_table.as_retriever` function is used to initialize a retriever object with specific search arguments (`'k':25`), which likely defines the number of search results to consider.
#
# - **Prompt Template :** The `PromptTemplate` was defined in the previous step that instructs how to use the context to answer a question. It emphasizes not to fabricate answers if the information is unavailable. The template also outlines the structure for the expected JSON output with various product and supplier details.

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# Create a retriever from the vector store
retriever = db_openai_table.as_retriever(search_kwargs={'k': 25})

# Helper to concatenate retrieved document chunks into a single context string
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Build the RAG chain using LCEL (LangChain Expression Language)
retrieval_chain = (
    {"context": retriever | format_docs, "input": RunnablePassthrough()}
    | prompt_template
    | llm
    | StrOutputParser()
)

# Invoke the chain
question = "Suggest a keyboard with a rating 4 or more"
response = retrieval_chain.invoke(question)

# Display the answer
print(response)

print("💯This is the end of the demo. Thank you for your attention!")
print("📸 Please take a screenshot!")
# Out:
# [
#   {
#     "PRODUCT_ID": "P_0129",
#     "PRODUCT_NAME": "Arteck Split Ergonomic Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Arteck Split Ergonomic Keyboard with Cushioned Wrist and Palm Rest, 2.4G USB Wireless Comfortable Natural Ergonomic Split Keyboard",
#     "UNIT_PRICE": "246,11",
#     "SUPPLIER_ID": 1005,
#     "SUPPLIER_NAME": "Precision Dynamics",
#     "LEAD_TIME_DAYS": 11,
#     "MIN_ORDER": 26,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Otto-Hahn-Straße 12, 44227 Dortmund, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Dortmund",
#     "STOCK_QUANTITY": 768,
#     "MANUFACTURER": "Arteck",
#     "RATING": 4
#   },
#   {
#     "PRODUCT_ID": "P_0141",
#     "PRODUCT_NAME": "Corsair K95 RGB Platinum XT Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Corsair OPX Optical-Mechanical Keyswitches, 6 Key Rollover, RGB Backlighting, Dedicated Media Controls",
#     "UNIT_PRICE": "209,99",
#     "SUPPLIER_ID": 1021,
#     "SUPPLIER_NAME": "Hyper Semicon",
#     "LEAD_TIME_DAYS": 5,
#     "MIN_ORDER": 10,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Lange Str. 55, 80331 Munich, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Munich",
#     "STOCK_QUANTITY": 50,
#     "MANUFACTURER": "Corsair",
#     "RATING": 4
#   },
#   {
#     "PRODUCT_ID": "P_0175",
#     "PRODUCT_NAME": "Logitech G613 LIGHTSPEED Wireless Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Romber G Mechanical Keyswitches, 18-Hour Battery Life, LIGHTSPEED Wireless Technology",
#     "UNIT_PRICE": "129,99",
#     "SUPPLIER_ID": 1005,
#     "SUPPLIER_NAME": "Precision Dynamics",
#     "LEAD_TIME_DAYS": 2,
#     "MIN_ORDER": 50,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Nordstraße 6, 80937 Munich, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Munich",
#     "STOCK_QUANTITY": 200,
#     "MANUFACTURER": "Logitech",
#     "RATING": 4
#   },
#   {
#     "PRODUCT_ID": "P_0157",
#     "PRODUCT_NAME": "Logitech G915 LIGHTSPEED Wireless RGB Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "RGB Backlighting, Low Profile Mechanical Switches, 30-Hour Battery Life, 5 Programmable Keys",
#     "UNIT_PRICE": "229,99",
#     "SUPPLIER_ID": 1037,
#     "SUPPLIER_NAME": "Crystal Circuits",
#     "LEAD_TIME_DAYS": 9,
#     "MIN_ORDER": 40,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Lindenstraße 20, 50933 Cologne, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Cologne",
#     "STOCK_QUANTITY": 100,
#     "MANUFACTURER": "Logitech",
#     "RATING": 5
#   },
#   {
#     "PRODUCT_ID": "P_0150",
#     "PRODUCT_NAME": "Kingston HyperX Alloy FPS Pro Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Tenkeyless Design, Red Mechanical Switches, RGB Backlighting",
#     "UNIT_PRICE": "109,99",
#     "SUPPLIER_ID": 1030,
#     "SUPPLIER_NAME": "Smart Networks",
#     "LEAD_TIME_DAYS": 9,
#     "MIN_ORDER": 15,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "An der Kaimbrücke 9, 80331 Munich, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Munich",
#     "STOCK_QUANTITY": 200,
#     "MANUFACTURER": "Kingston",
#     "RATING": 4
#   },
#   {
#     "PRODUCT_ID": "P_0161",
#     "PRODUCT_NAME": "Corsair K70 RGB MK.2 Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Cherry MX Keyswitches, RGB Backlighting, Aircraft-Grade Aluminum Frame, 8MB Profile Storage",
#     "UNIT_PRICE": "169,99",
#     "SUPPLIER_ID": 1041,
#     "SUPPLIER_NAME": "Blue Supplies",
#     "LEAD_TIME_DAYS": 4,
#     "MIN_ORDER": 20,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Carl-Benz-Straße 1, 60528 Frankfurt, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Frankfurt",
#     "STOCK_QUANTITY": 220,
#     "MANUFACTURER": "Corsair",
#     "RATING": 5
#   },
#   {
#     "PRODUCT_ID": "P_0162",
#     "PRODUCT_NAME": "Razer BlackWidow V3 Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Razer Green Switches, RGB Chroma Backlighting, Dedicated Media Controls",
#     "UNIT_PRICE": "119,99",
#     "SUPPLIER_ID": 1042,
#     "SUPPLIER_NAME": "Fusion Dynamics",
#     "LEAD_TIME_DAYS": 2,
#     "MIN_ORDER": 30,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Sonnenstraße 14, 80331 Munich, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Munich",
#     "STOCK_QUANTITY": 300,
#     "MANUFACTURER": "Razer",
#     "RATING": 5
#   },
#   {
#     "PRODUCT_ID": "P_0169",
#     "PRODUCT_NAME": "SteelSeries Apex Pro TKL Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "OmniPoint Adjustable Switches, RGB Backlighting, Aircraft-Grade Aluminum Alloy Frame",
#     "UNIT_PRICE": "199,99",
#     "SUPPLIER_ID": 1049,
#     "SUPPLIER_NAME": "Hyper Supplies",
#     "LEAD_TIME_DAYS": 8,
#     "MIN_ORDER": 10,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Königsberger Str. 23, 70563 Stuttgart, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Stuttgart",
#     "STOCK_QUANTITY": 180,
#     "MANUFACTURER": "SteelSeries",
#     "RATING": 5
#   }
# ]
# 💯This is the end of the demo. Thank you for your attention!
# 📸 Please take a screenshot!

# %% [markdown]
# ## 🔍 Try Your Own Queries
#
# Use the RAG chain to explore the product catalog with different questions. Change the `question` variable below and re-run the cell to get contextually relevant answers powered by the vector search + LLM.
#
# Some example questions you can try:
# - **Features in description:** `"Find a keyboard with RGB backlighting"`
# - **Price-sensitive:** `"What is the cheapest wireless mouse available?"`
# - **Rating filter:** `"Suggest a headset with a rating of 5"`

# %%
from IPython.display import Markdown

# ✏️ Change this question to explore the product catalog
question = "Find a single keyboard with RGB backlighting"

# Example questions to try (uncomment one):
# question = "What is the single cheapest wireless mouse available?"
# question = "Suggest a single headset with a rating of 5"

response = retrieval_chain.invoke(question)
display(Markdown(f"**Query:** {question}\n\n**Answer:**\n\n{response}"))
# Out:
# **Query:** Find a single keyboard with RGB backlighting
#
# **Answer:**
#
# [
#   {
#     "PRODUCT_ID": "P_0161",
#     "PRODUCT_NAME": "Corsair K70 RGB MK.2 Mechanical Gaming Keyboard",
#     "CATEGORY": "IT Accessories",
#     "DESCRIPTION": "Cherry MX Keyswitches, RGB Backlighting, Aircraft-Grade Aluminum Frame, 8MB Profile Storage",
#     "UNIT_PRICE": "169,99",
#     "SUPPLIER_ID": 1041,
#     "SUPPLIER_NAME": "Blue Supplies",
#     "LEAD_TIME_DAYS": 4,
#     "MIN_ORDER": 20,
#     "CURRENCY": "EURO",
#     "SUPPLIER_COUNTRY": "Germany",
#     "SUPPLIER_ADDRESS": "Carl-Benz-Straße 1, 60528 Frankfurt, Germany",
#     "STATUS": "AVAILABLE",
#     "SUPPLIER_CITY": "Frankfurt",
#     "STOCK_QUANTITY": 220,
#     "MANUFACTURER": "Corsair",
#     "RATING": 5
#   }
# ]

# %%
import json, re, csv

def parse_products(raw_response):
    """Parse the LLM JSON response, stripping any markdown code fences."""
    raw = re.sub(r"^```(?:json)?\s*|\s*```$", "", str(raw_response).strip(), flags=re.MULTILINE)
    try:
        result = json.loads(raw)
        return result if isinstance(result, list) else [result]
    except json.JSONDecodeError:
        return []

def parse_price(price_str):
    """Parse European price format (e.g. '169,99') into float."""
    try:
        return float(str(price_str).replace(".", "").replace(",", ".").strip())
    except (ValueError, TypeError):
        return float("inf")

# ── Load the ground-truth catalog for cross-referencing ──
# Use utf-8-sig to strip any BOM from the CSV header
with open("data/product_catalog.csv", encoding="utf-8-sig") as f:
    reader = csv.DictReader(f, delimiter=";")
    catalog = list(reader)

# Quick sanity check on column names
print(f"📋 Catalog columns: {list(catalog[0].keys())}")
print(f"📋 Total products:  {len(catalog)}")

# Pre-compute subsets for validation
catalog_wireless_mice = [
    row for row in catalog
    if "mouse" in row["PRODUCT_NAME"].lower() and "wireless" in (row["PRODUCT_NAME"] + row["DESCRIPTION"]).lower()
]
cheapest_wireless_mouse_price = min(parse_price(m["UNIT_PRICE"]) for m in catalog_wireless_mice)
cheapest_wireless_mouse_ids = {
    m["PRODUCT_ID"] for m in catalog_wireless_mice
    if parse_price(m["UNIT_PRICE"]) == cheapest_wireless_mouse_price
}

catalog_rgb_keyboards = [
    row for row in catalog
    if "keyboard" in row["PRODUCT_NAME"].lower()
    and re.search(r"rgb(?:\s+\w+)*\s+backlight\w*", row["DESCRIPTION"], re.IGNORECASE)
]
catalog_rgb_keyboard_ids = {row["PRODUCT_ID"] for row in catalog_rgb_keyboards}

catalog_headsets_rating5 = [
    row for row in catalog
    if "headset" in row["PRODUCT_NAME"].lower() and int(row.get("RATING", 0)) == 5
]
catalog_headset5_ids = {row["PRODUCT_ID"] for row in catalog_headsets_rating5}

print(f"\n📦 Catalog ground truth:")
print(f"   • RGB backlight keyboards:       {len(catalog_rgb_keyboards)}")
print(f"   • Wireless mice:                 {len(catalog_wireless_mice)} (cheapest: €{cheapest_wireless_mouse_price:.2f})")
print(f"   • Headsets with rating 5:        {len(catalog_headsets_rating5)}")

# ── Test cases with robust validation ──
test_cases = [
    {
        "question": "Find all keyboards with RGB backlighting",
        "validator": lambda p: (
            p.get("PRODUCT_ID", "") in catalog_rgb_keyboard_ids,
            f"Product must be a known RGB-backlight keyboard (catalog has {len(catalog_rgb_keyboards)})"
        ),
    },
    {
        "question": "What is the cheapest wireless mouse available? Return only one.",
        "validator": lambda p: (
            p.get("PRODUCT_ID", "") in cheapest_wireless_mouse_ids
            and abs(parse_price(p.get("UNIT_PRICE", "0")) - cheapest_wireless_mouse_price) < 0.02,
            f"Must be the cheapest wireless mouse at €{cheapest_wireless_mouse_price:.2f} "
            f"(ID(s): {cheapest_wireless_mouse_ids})"
        ),
    },
    {
        "question": "Suggest a headset with a rating of 5. Return only one.",
        "validator": lambda p: (
            p.get("PRODUCT_ID", "") in catalog_headset5_ids
            and int(p.get("RATING", 0)) == 5,
            f"Must be a headset with RATING=5 from catalog (catalog has {len(catalog_headsets_rating5)})"
        ),
    },
]

# ── Run all test cases ──
overall_passed = 0
overall_failed = 0
summary_rows = []

for i, tc in enumerate(test_cases, 1):
    q = tc["question"]
    print(f"\n{'='*80}")
    print(f"  Test {i}/{len(test_cases)}: {q}")
    print(f"{'='*80}")

    resp = retrieval_chain.invoke(q)
    products = parse_products(resp)

    if not products:
        print("  ⚠️  No products returned or JSON could not be parsed.")
        summary_rows.append((q, 0, 0, 0))
        continue

    tc_passed = 0
    tc_failed = 0
    _, rule_desc = tc["validator"](products[0])

    for p in products:
        ok, _ = tc["validator"](p)
        pid = p.get("PRODUCT_ID", "?")
        name = p.get("PRODUCT_NAME", "?")
        price = p.get("UNIT_PRICE", "?")
        rating = p.get("RATING", "?")
        stock = p.get("STOCK_QUANTITY", "?")

        if ok:
            tc_passed += 1
            mark = "✅"
        else:
            tc_failed += 1
            mark = "❌"
        print(f"  {mark} {pid} | {name} | €{price} | ⭐{rating} | stock:{stock}")

    overall_passed += tc_passed
    overall_failed += tc_failed
    summary_rows.append((q, len(products), tc_passed, tc_failed))

    print(f"\n  📏 Rule: {rule_desc}")
    print(f"  📊 {tc_passed}/{len(products)} passed" + (" ✅" if tc_failed == 0 else f" — ⚠️ {tc_failed} failed"))

# ── Final summary ──
print(f"\n{'='*80}")
print(f"  📋 SUMMARY")
print(f"{'='*80}")
for q, total, p, f in summary_rows:
    icon = "✅" if f == 0 and total > 0 else ("⚠️" if total > 0 else "❓")
    print(f"  {icon} [{p}/{total}] {q}")
print(f"\n  🏁 Overall: {overall_passed} passed / {overall_failed} failed across {len(test_cases)} queries")
accuracy = overall_passed / max(overall_passed + overall_failed, 1) * 100
print(f"  🎯 Accuracy: {accuracy:.1f}%")
print(f"{'='*80}")
# Out:
# 📋 Catalog columns: ['PRODUCT_ID', 'PRODUCT_NAME', 'CATEGORY', 'DESCRIPTION', 'UNIT_PRICE', 'SUPPLIER_ID', 'SUPPLIER_NAME', 'LEAD_TIME_DAYS', 'MIN_ORDER', 'CURRENCY', 'SUPPLIER_COUNTRY', 'SUPPLIER_ADDRESS', 'STATUS', 'SUPPLIER_CITY', 'STOCK_QUANTITY', 'MANUFACTURER', 'CITY_LAT', 'CITY_LONG', 'RATING']
# 📋 Total products:  75
#
# 📦 Catalog ground truth:
#    • RGB backlight keyboards:      6
#    • Wireless mice:                 15 (cheapest: €34.75)
#    • Headsets with rating 5:        3
#
# ================================================================================
#   Test 1/3: Find all keyboards with RGB backlighting
# ================================================================================
#   ✅ P_0161 | Corsair K70 RGB MK.2 Mechanical Gaming Keyboard | €169,99 | ⭐5 | stock:220
#   ✅ P_0141 | Corsair K95 RGB Platinum XT Mechanical Gaming Keyboard | €209,99 | ⭐4 | stock:50
#   ✅ P_0157 | Logitech G915 LIGHTSPEED Wireless RGB Mechanical Gaming Keyboard | €229,99 | ⭐5 | stock:100
#   ✅ P_0150 | Kingston HyperX Alloy FPS Pro Mechanical Gaming Keyboard | €109,99 | ⭐4 | stock:200
#   ✅ P_0162 | Razer BlackWidow V3 Mechanical Gaming Keyboard | €119,99 | ⭐5 | stock:300
#   ✅ P_0169 | SteelSeries Apex Pro TKL Mechanical Gaming Keyboard | €199,99 | ⭐5 | stock:180
#
#   📏 Rule: Product must be a known RGB-backlight keyboard (catalog has 6)
#   📊 6/6 passed ✅
#
# ================================================================================
#   Test 2/3: What is the cheapest wireless mouse available? Return only one.
# ================================================================================
#   ✅ P_0110 | Logitech Signature M650 L Full Size Wireless Mouse | €34,75 | ⭐5 | stock:104
#
#   📏 Rule: Must be the cheapest wireless mouse at €34.75 (ID(s): {'P_0110', 'P_0111'})
#   📊 1/1 passed ✅
#
# ================================================================================
#   Test 3/3: Suggest a headset with a rating of 5
# ================================================================================
#   ✅ P_0149 | Turtle Beach Stealth 700 Gen 2 Wireless Headset | €179,99 | ⭐5 | stock:150
#
#   📏 Rule: Must be a headset with RATING=5 from catalog (catalog has 3)
#   📊 1/1 passed ✅
#
# ================================================================================
#   📋 SUMMARY
# ================================================================================
#   ✅ [6/6] Find all keyboards with RGB backlighting
#   ✅ [1/1] What is the cheapest wireless mouse available? Return only one.
#   ✅ [1/1] Suggest a headset with a rating of 5
#
#   🏁 Overall: 8 passed / 0 failed across 3 queries
#   🎯 Accuracy: 100.0%
# ================================================================================

# %% [markdown]
# > At this point we have successfully implemented the final step of Retrieval Process and enabled generation of the **contextually relevant answer** based on user's query.
# >
# > ![rag_full](./images/rag_full.png)

# %% [markdown]
# ### Close Database Connection
# Ensure the database connection is closed when the notebook is no longer in use.

# %%
if cursor:
    cursor.close()
if connection:
    connection.close()
print("Database connection closed.")
